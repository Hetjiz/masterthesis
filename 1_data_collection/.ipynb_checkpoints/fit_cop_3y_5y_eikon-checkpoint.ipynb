# %% [markdown]
# # Copula Fitting for Feature Variables (cop_3y & cop_5y) - eikon
# Copulas are fitted using a three years and a five years rolling window.
#
# _search in file for "CONFIG" to find code to be configurated_

# %%
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
import pathlib
import pandas as pd
import platform
import pyvinecopulib as pv
import random
import seaborn as sns
from sqlalchemy import create_engine
import sys

from fitcopula import fitShiftedAnnually
from fitcopula import fitShiftedAnnuallyTest
from fitcopula import fitShiftedAnnuallyRandTest
from fitcopula import singleStockCheck

date_format = "%Y-%m-%d"

# %%
# copula family set (parametric only):
'''
family_set = [pv.BicopFamily.indep,
            pv.BicopFamily.gaussian,
            pv.BicopFamily.student,
            pv.BicopFamily.clayton,
            pv.BicopFamily.gumbel,
            pv.BicopFamily.frank,
            pv.BicopFamily.joe,
            pv.BicopFamily.bb1,
            pv.BicopFamily.bb6,
            pv.BicopFamily.bb7,
            pv.BicopFamily.bb8]
'''
# Out:
# '\nfamily_set = [pv.BicopFamily.indep,\n            pv.BicopFamily.gaussian,\n            pv.BicopFamily.student,\n            pv.BicopFamily.clayton,\n            pv.BicopFamily.gumbel,\n            pv.BicopFamily.frank,\n            pv.BicopFamily.joe,\n            pv.BicopFamily.bb1,\n            pv.BicopFamily.bb6,\n            pv.BicopFamily.bb7,\n            pv.BicopFamily.bb8]\n'

# %%
# copula family set (kendalL's tau inversion only):
family_set = [pv.BicopFamily.indep,
            pv.BicopFamily.gaussian,
            pv.BicopFamily.student,
            pv.BicopFamily.clayton,
            pv.BicopFamily.gumbel,
            pv.BicopFamily.frank,
            pv.BicopFamily.joe]

# %%
# start psql server
# !brew services start postgresql
                                                         
# psql database connections
eikon_data_timeseries = create_engine('postgresql://master:thesis@localhost:5432/eikon_data_timeseries')
stock_market_data     = create_engine('postgresql://master:thesis@localhost:5432/stock_market_data')
# Out:
# Service `postgresql` already started, use `brew services restart postgresql` to restart.

# %%
my_os = platform.system()
print("OS in my system : ",my_os)

if my_os == "Windows":
    path = str(pathlib.Path().absolute()) + '\\'
    slash = '\\'
else:
    path = str(pathlib.Path().absolute()) + '/'
    slash = '/'
# Out:
# OS in my system :  Darwin

# %% [markdown]
# ## General stock information (from eikon, e)

# %%
# load general stock information
e_stock_info = pd.read_excel(path + 'data_artifacts' + slash + 'eikon_general_stock_info.xlsx')

# %%
# oranizing columns
e_stock_info = e_stock_info.drop(columns=['name', 'equity_type'])

# convert date columns to datetime
e_stock_info['inc_date'] = pd.to_datetime(e_stock_info['inc_date'])
e_stock_info['ipo_date'] = pd.to_datetime(e_stock_info['ipo_date'])
e_stock_info['fy_end_date'] = pd.to_datetime(e_stock_info['fy_end_date'])
e_stock_info['fy_end_date'] = e_stock_info['fy_end_date'].dt.month
e_stock_info.head()
# Out:
#         ric          isin   inc_date   ipo_date          naics  fy_end_date  \
# 0  AAPL.ITC  US0378331005 1977-01-03 1980-12-12  Manufacturing          9.0
# 1  AMZN.ITC  US0231351067 1996-05-28 1997-05-15   Retail Trade         12.0
# 2  TSLA.ITC  US88160R1014 2003-07-01 2010-06-09  Manufacturing         12.0
# 3  MSFT.ITC  US5949181045 1993-09-22 1986-03-13    Information          6.0
# 4   TRI.ITC  CA8849037095 1977-12-28 2002-06-12    Information         12.0
#
#   symbol
# 0   AAPL
# 1   AMZN
# 2   TSLA
# 3   MSFT
# 4    TRI

# %% [markdown]
# ## Data sets
#
# **eikon:**
# * e_stock_returns (stock log returns)
# * e_market_spx_returns (market log returns | market proxy: S&P 500 Index - CBOE)
# * e_market_ndx_returns (market log returns | market proxy: NASDAQ 100 Index)

# %%
# load data sets

# ---------------- CONFIG ----------------
# month_day_hour_name to be configurated in table name

e_stock_returns       = pd.read_sql("select * from \"1_1_17_e_stock_returns\"", stock_market_data);
e_stock_returns       = e_stock_returns.drop(columns='index').sort_values(by=['symbol', 'date'])

e_market_spx_returns  = pd.read_sql("select * from \"1_1_18_e_market_spx_returns\"", stock_market_data);
e_market_spx_returns  = e_market_spx_returns.drop(columns='index').sort_values(by=['date'])

e_market_ndx_returns  = pd.read_sql("select * from \"1_1_18_e_market_ndx_returns\"", stock_market_data);
e_market_ndx_returns  = e_market_ndx_returns.drop(columns='index').sort_values(by=['date'])

# %%
print('Free of duplicates:')
print(len(e_stock_returns) == len(e_stock_returns.drop_duplicates()))
print(len(e_market_spx_returns) == len(e_market_spx_returns.drop_duplicates()))
print(len(e_market_ndx_returns) == len(e_market_ndx_returns.drop_duplicates()))
# Out:
# Free of duplicates:
# True
# True
# True

# %% [markdown]
# ## Copula Fitting
# Tau is taken as universal dependency measure as it is reflects the copula regardless of the underlying copula family. The _pyvinecopulib.Bicop()_ method from Python package _pyvinecopulib_ returns the best fitting copula on given input data. The copulas are fitted per stock company for each year between 2011 and 2020 taking into account deviating fiscal years. Rolling windows are not considered.

# %% [markdown]
# ### 3 Years Window
# **Stock returns and S&P 500 Index - CBOE:**

# %%
e_cop_3y_spx = fitShiftedAnnually(e_stock_returns, e_market_spx_returns, e_stock_info, family_set, 3)
display(e_cop_3y_spx)
print('Proportion of Tau zero values:')
print(((e_cop_3y_spx['tau'] == 0).sum())/(len(e_cop_3y_spx)))
# Out:
# <pyvinecopulib.FitControlsBicop>
# Family set: Independence, Gaussian, Student, Clayton, Gumbel, Frank, Joe
# Parametric method: mle
# Nonparametric method: quadratic
# Nonparametric multiplier: 1
# Weights: no
# Selection criterion: bic
# Preselect families: yes
# mBIC prior probability: 0.9
# Number of threads: 1
#       symbol  year                family  rotation       tau  \
# 0          A  2000   BicopFamily.clayton         0  0.232904
# 1          A  2001  BicopFamily.gaussian         0  0.344151
# 2          A  2002     BicopFamily.frank         0  0.391592
# 3          A  2003   BicopFamily.student         0  0.471121
# 4          A  2004   BicopFamily.student         0  0.485946
# ...      ...   ...                   ...       ...       ...
# 53051   ZYXI  2017     BicopFamily.indep         0  0.000000
# 53052   ZYXI  2018     BicopFamily.indep         0  0.000000
# 53053   ZYXI  2019     BicopFamily.indep         0  0.000000
# 53054   ZYXI  2020    BicopFamily.gumbel       180  0.145354
# 53055   ZYXI  2021   BicopFamily.student         0  0.165212
#
#                                          parameters
# 0                            [[0.6072369990140342]]
# 1                            [[0.5146428107788528]]
# 2                             [[4.046358152131664]]
# 3       [[0.6743140558777078], [8.493205548935737]]
# 4        [[0.6913252974545696], [6.38771665653571]]
# ...                                             ...
# 53051                                            []
# 53052                                            []
# 53053                                            []
# 53054                        [[1.1700748988373868]]
# 53055  [[0.2566108019984214], [3.6554028531942553]]
#
# [53056 rows x 6 columns]
# Proportion of Tau zero values:
# 0.107188630880579

# %%
e_cop_3y_spx.describe()
# Out:
#                year      rotation           tau
# count  53056.000000  53056.000000  53056.000000
# mean    2012.116877     35.931469      0.257899
# std        6.099199     72.048891      0.159994
# min     2000.000000      0.000000     -0.144289
# 25%     2007.000000      0.000000      0.120193
# 50%     2013.000000      0.000000      0.271245
# 75%     2017.000000      0.000000      0.382383
# max     2021.000000    270.000000      0.696102

# %%
sns.histplot(data = e_cop_3y_spx, x = 'tau', log_scale = (False, True), bins = 200)
# Out:
# <AxesSubplot:xlabel='tau', ylabel='Count'>

# %%
# safe to excel
today = datetime.today()
storage_name = str(today.month) + '_' + str(today.day) + '_' + str(today.hour) + '_' + 'e_cop_3y_spx.xlsx'

e_cop_3y_spx.to_excel(path + 'data_artifacts' + slash + 'copulas' + slash + storage_name)

# %% [markdown]
# **Stock returns and NASDAQ 100 Index:**

# %%
e_cop_3y_ndx = fitShiftedAnnually(e_stock_returns, e_market_ndx_returns, e_stock_info, family_set, 3)
display(e_cop_3y_ndx)
print('Proportion of Tau zero values:')
print(((e_cop_3y_ndx['tau'] == 0).sum())/(len(e_cop_3y_ndx)))
# Out:
# <pyvinecopulib.FitControlsBicop>
# Family set: Independence, Gaussian, Student, Clayton, Gumbel, Frank, Joe
# Parametric method: mle
# Nonparametric method: quadratic
# Nonparametric multiplier: 1
# Weights: no
# Selection criterion: bic
# Preselect families: yes
# mBIC prior probability: 0.9
# Number of threads: 1
#       symbol  year                family  rotation       tau  \
# 0          A  2000  BicopFamily.gaussian         0  0.308815
# 1          A  2001  BicopFamily.gaussian         0  0.392712
# 2          A  2002  BicopFamily.gaussian         0  0.410796
# 3          A  2003   BicopFamily.student         0  0.500286
# 4          A  2004   BicopFamily.student         0  0.512234
# ...      ...   ...                   ...       ...       ...
# 53051   ZYXI  2017     BicopFamily.indep         0  0.000000
# 53052   ZYXI  2018     BicopFamily.indep         0  0.000000
# 53053   ZYXI  2019  BicopFamily.gaussian         0  0.064196
# 53054   ZYXI  2020    BicopFamily.gumbel       180  0.143369
# 53055   ZYXI  2021   BicopFamily.student         0  0.161109
#
#                                           parameters
# 0                             [[0.4662840681841525]]
# 1                             [[0.5784852602453654]]
# 2                             [[0.6014190798029045]]
# 3        [[0.7074248856140111], [4.980731632175956]]
# 4        [[0.7205640815305424], [4.391514552882655]]
# ...                                              ...
# 53051                                             []
# 53052                                             []
# 53053                        [[0.10066726075304831]]
# 53054                         [[1.1673632694974012]]
# 53055  [[0.25037605075392666], [3.8324496780564874]]
#
# [53056 rows x 6 columns]
# Proportion of Tau zero values:
# 0.1204576296743064

# %%
e_cop_3y_ndx.describe()
# Out:
#                year      rotation           tau
# count  53056.000000  53056.000000  53056.000000
# mean    2012.116877     39.802473      0.228409
# std        6.099199     74.779118      0.146936
# min     2000.000000      0.000000     -0.127874
# 25%     2007.000000      0.000000      0.107419
# 50%     2013.000000      0.000000      0.231175
# 75%     2017.000000      0.000000      0.341822
# max     2021.000000    270.000000      0.691751

# %%
sns.histplot(data = e_cop_3y_ndx, x = 'tau', log_scale = (False, True), bins = 200)
# Out:
# <AxesSubplot:xlabel='tau', ylabel='Count'>

# %%
# safe to excel
today = datetime.today()
storage_name = str(today.month) + '_' + str(today.day) + '_' + str(today.hour) + '_' + 'e_cop_3y_ndx.xlsx'

e_cop_3y_ndx.to_excel(path + 'data_artifacts' + slash + 'copulas' + slash + storage_name)

# %% [markdown]
# ### 5 Years Window
# **Stock returns and S&P 500 Index - CBOE:**

# %%
e_cop_5y_spx = fitShiftedAnnually(e_stock_returns, e_market_spx_returns, e_stock_info, family_set, 5)
display(e_cop_5y_spx)
print('Proportion of Tau zero values:')
print(((e_cop_5y_spx['tau'] == 0).sum())/(len(e_cop_5y_spx)))
# Out:
# <pyvinecopulib.FitControlsBicop>
# Family set: Independence, Gaussian, Student, Clayton, Gumbel, Frank, Joe
# Parametric method: mle
# Nonparametric method: quadratic
# Nonparametric multiplier: 1
# Weights: no
# Selection criterion: bic
# Preselect families: yes
# mBIC prior probability: 0.9
# Number of threads: 1
#       symbol  year                family  rotation       tau  \
# 0          A  2000   BicopFamily.clayton         0  0.232904
# 1          A  2001  BicopFamily.gaussian         0  0.344151
# 2          A  2002     BicopFamily.frank         0  0.391592
# 3          A  2003     BicopFamily.frank         0  0.417179
# 4          A  2004     BicopFamily.frank         0  0.425203
# ...      ...   ...                   ...       ...       ...
# 53263   ZYXI  2017     BicopFamily.indep         0  0.000000
# 53264   ZYXI  2018     BicopFamily.indep         0  0.000000
# 53265   ZYXI  2019     BicopFamily.indep         0  0.000000
# 53266   ZYXI  2020    BicopFamily.gumbel       180  0.098797
# 53267   ZYXI  2021    BicopFamily.gumbel       180  0.120372
#
#                    parameters
# 0      [[0.6072369990140342]]
# 1      [[0.5146428107788528]]
# 2       [[4.046358152131664]]
# 3        [[4.40261248027939]]
# 4        [[4.51897345122444]]
# ...                       ...
# 53263                      []
# 53264                      []
# 53265                      []
# 53266  [[1.1096277275001405]]
# 53267  [[1.1368445179527842]]
#
# [53268 rows x 6 columns]
# Proportion of Tau zero values:
# 0.09018547720958174

# %%
e_cop_5y_spx.describe()
# Out:
#                year      rotation           tau
# count  53268.000000  53268.000000  53268.000000
# mean    2012.121367     27.986033      0.252283
# std        6.096526     65.316221      0.156976
# min     2000.000000      0.000000     -0.119207
# 25%     2007.000000      0.000000      0.113962
# 50%     2013.000000      0.000000      0.262205
# 75%     2017.000000      0.000000      0.378014
# max     2021.000000    270.000000      0.674719

# %%
sns.histplot(data = e_cop_5y_spx, x = 'tau', log_scale = (False, True), bins = 200)
# Out:
# <AxesSubplot:xlabel='tau', ylabel='Count'>

# %%
# safe to excel
today = datetime.today()
storage_name = str(today.month) + '_' + str(today.day) + '_' + str(today.hour) + '_' + 'e_cop_5y_spx.xlsx'

e_cop_5y_spx.to_excel(path + 'data_artifacts' + slash + 'copulas' + slash + storage_name)

# %% [markdown]
# **Stock returns and NASDAQ 100 Index:**

# %%
e_cop_5y_ndx = fitShiftedAnnually(e_stock_returns, e_market_ndx_returns, e_stock_info, family_set, 5)
display(e_cop_5y_ndx)
print('Proportion of Tau zero values:')
print(((e_cop_5y_ndx['tau'] == 0).sum())/(len(e_cop_5y_ndx)))
# Out:
# <pyvinecopulib.FitControlsBicop>
# Family set: Independence, Gaussian, Student, Clayton, Gumbel, Frank, Joe
# Parametric method: mle
# Nonparametric method: quadratic
# Nonparametric multiplier: 1
# Weights: no
# Selection criterion: bic
# Preselect families: yes
# mBIC prior probability: 0.9
# Number of threads: 1
#       symbol  year                family  rotation       tau  \
# 0          A  2000  BicopFamily.gaussian         0  0.308815
# 1          A  2001  BicopFamily.gaussian         0  0.392712
# 2          A  2002  BicopFamily.gaussian         0  0.410796
# 3          A  2003   BicopFamily.student         0  0.435484
# 4          A  2004   BicopFamily.student         0  0.446790
# ...      ...   ...                   ...       ...       ...
# 53263   ZYXI  2017     BicopFamily.indep         0  0.000000
# 53264   ZYXI  2018     BicopFamily.indep         0  0.000000
# 53265   ZYXI  2019     BicopFamily.indep         0  0.000000
# 53266   ZYXI  2020    BicopFamily.gumbel       180  0.100290
# 53267   ZYXI  2021   BicopFamily.student         0  0.116618
#
#                                        parameters
# 0                          [[0.4662840681841525]]
# 1                          [[0.5784852602453654]]
# 2                          [[0.6014190798029045]]
# 3      [[0.6319421151248448], [6.01687796968114]]
# 4      [[0.6456051797363316], [4.50773277914734]]
# ...                                           ...
# 53263                                          []
# 53264                                          []
# 53265                                          []
# 53266                       [[1.111469277805871]]
# 53267  [[0.1821599292578921], [6.27791824363185]]
#
# [53268 rows x 6 columns]
# Proportion of Tau zero values:
# 0.10250056318990763

# %%
e_cop_5y_ndx.describe()
# Out:
#                year      rotation           tau
# count  53268.000000  53268.000000  53268.000000
# mean    2012.121367     30.824510      0.224415
# std        6.096526     67.871637      0.144473
# min     2000.000000      0.000000     -0.122992
# 25%     2007.000000      0.000000      0.101593
# 50%     2013.000000      0.000000      0.225888
# 75%     2017.000000      0.000000      0.339517
# max     2021.000000    270.000000      0.655846

# %%
sns.histplot(data = e_cop_5y_ndx, x = 'tau', log_scale = (False, True), bins = 200)
# Out:
# <AxesSubplot:xlabel='tau', ylabel='Count'>

# %%
# safe to excel
today = datetime.today()
storage_name = str(today.month) + '_' + str(today.day) + '_' + str(today.hour) + '_' + 'e_cop_5y_ndx.xlsx'

e_cop_5y_ndx.to_excel(path + 'data_artifacts' + slash + 'copulas' + slash + storage_name)
