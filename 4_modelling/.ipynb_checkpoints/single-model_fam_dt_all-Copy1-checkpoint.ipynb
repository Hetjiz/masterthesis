# %% [markdown]
# # Decision Tree (copula family) [all]
# This is a simple, yet powerful algorithm that can be used for both regression and classification problems. It works well with categorical data, as well as data with non-linear relationships.
#
# https://scikit-learn.org/stable/modules/tree.html#classification
#
# tree.DecisionTreeClassifier()
#
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}
#
# **_bayesian hyperparameter tuning_**

# %%
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pathlib
import platform
import seaborn as sns
from sklearn import linear_model
from sklearn import tree
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler
from skopt import gp_minimize, space
from skopt.space import Real, Integer
import sys

from validation import cross_validation
from validation import performance_test_shifted

date_format = '%Y-%m-%d'

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.max_colwidth = None

# %%
# config 'all', 'vif_5' or 'vif_10'
vif = 'all'

# config model
ml_algorithm = tree.DecisionTreeClassifier
filename = 'single-model_fam_dt'

# %%
my_os = platform.system()
print('OS in my system: ',my_os)

if my_os == 'Windows':
    path = str(pathlib.Path().absolute()) + '\\'
    slash = '\\'
else:
    path = str(pathlib.Path().absolute()) + '/'
    slash = '/'

path_3 = path.replace('4_modelling', '3_data_pre-processing')
# Out:
# OS in my system:  Windows

# %% [markdown]
# ## Load Data

# %%
data_set = pd.read_csv(path_3 + 'data_artifacts' + slash + 'data_set_e_spx_3-' + vif + '.csv', index_col=0)

# %% [markdown]
# ## Original Target Model (no forecast horizon)
# ### Time Series Cross Validation on Default Model

# %%
default_model = ml_algorithm(random_state=23)
default_model.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 23,
#  'splitter': 'best'}

# %%
default_model_scores_ori = cross_validation (data_set, default_model, 'fam_target_ori')
pd.DataFrame(default_model_scores_ori).describe()
# Out:
#        auc_train  auc_valid  acc_train  acc_valid  prec_train  prec_valid  \
# count       10.0  10.000000       10.0  10.000000        10.0   10.000000
# mean         1.0   0.564204        1.0   0.308798         1.0    0.192235
# std          0.0   0.010449        0.0   0.023604         0.0    0.005055
# min          1.0   0.549219        1.0   0.274428         1.0    0.184397
# 25%          1.0   0.558914        1.0   0.296648         1.0    0.189157
# 50%          1.0   0.562965        1.0   0.302320         1.0    0.191024
# 75%          1.0   0.571660        1.0   0.323685         1.0    0.195452
# max          1.0   0.581050        1.0   0.350877         1.0    0.200994
#
#        rec_train  rec_valid  f1_train   f1_valid
# count       10.0  10.000000      10.0  10.000000
# mean         1.0   0.255694       1.0   0.247983
# std          0.0   0.019858       0.0   0.020762
# min          1.0   0.224952       1.0   0.217466
# 25%          1.0   0.248113       1.0   0.238507
# 50%          1.0   0.253370       1.0   0.249868
# 75%          1.0   0.270166       1.0   0.259101
# max          1.0   0.286698       1.0   0.282280

# %%
ax = pd.DataFrame(default_model_scores_ori).plot(figsize=(8,4))
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %% [markdown]
# ### Hyperparameter Optimization with Time Series Cross Validation
# - Bayesian optimization
# - https://scikit-optimize.github.io/stable/auto_examples/bayesian-optimization.html

# %%
# search space for the hyperparameters
space = [Integer(1, 50, name='max_depth'),
         Integer(2, 200, name='min_samples_split'),
         Integer(1, 200, name='min_samples_leaf')]

# %%
# objective function to minimize
def objective(params):
    max_depth, min_samples_split, min_samples_leaf = params
    model = ml_algorithm(max_depth=int(max_depth), min_samples_split=int(min_samples_split), min_samples_leaf=int(min_samples_leaf), random_state=23)
    scores = cross_validation(data_set, model, 'fam_target_ori')
    return -np.mean(scores['auc_valid'])

# perform the optimization
result = gp_minimize(objective, space, n_calls=100, n_random_starts=20, acq_func='EI', acq_optimizer='lbfgs', random_state=23, n_jobs=-1)

# optimal point and function value
print('Optimal point:', result.x)
print('Function value at optimal point:', result.fun)
ax = pd.DataFrame(result.func_vals).plot(figsize=(12,4))
# Out:
# Optimal point: [48, 2, 37]
# Function value at optimal point: -0.5600117687528228

# %% [markdown]
# ### Time Series Cross Validation on Optimal Model

# %%
# ---------------- config opt model -----------------
opt_model_ori = ml_algorithm(max_depth=48, min_samples_split=2, min_samples_leaf=37, random_state=23)

# %%
opt_model_ori_tscv_scores = cross_validation(data_set, opt_model_ori, 'fam_target_ori')
opt_model_ori_tscv_scores = pd.DataFrame(opt_model_ori_tscv_scores)
display(opt_model_ori_tscv_scores)
display(opt_model_ori_tscv_scores.describe())
# Out:
#    auc_train  auc_valid  acc_train  acc_valid  prec_train  prec_valid  \
# 0   0.597022   0.562681   0.254800   0.263784    0.218293    0.203641
# 1   0.601244   0.563237   0.266087   0.231762    0.227499    0.208418
# 2   0.601953   0.569654   0.276941   0.275385    0.230900    0.211579
# 3   0.602676   0.553863   0.303472   0.193347    0.236425    0.196961
# 4   0.594848   0.555458   0.272829   0.163121    0.217203    0.203605
# 5   0.594601   0.554861   0.284570   0.179003    0.216966    0.201420
# 6   0.597653   0.559657   0.298051   0.204676    0.226275    0.217936
# 7   0.599962   0.562204   0.277405   0.204575    0.228232    0.217063
# 8   0.605539   0.554211   0.307566   0.206194    0.244252    0.196729
# 9   0.605734   0.564290   0.303338   0.241599    0.244131    0.209208
#
#    rec_train  rec_valid  f1_train  f1_valid
# 0   0.218293   0.177544  0.277610  0.188134
# 1   0.227499   0.176203  0.285236  0.191609
# 2   0.230900   0.196912  0.284227  0.217707
# 3   0.236425   0.177308  0.286818  0.182790
# 4   0.217203   0.157444  0.265012  0.179311
# 5   0.216966   0.152569  0.262353  0.170566
# 6   0.226275   0.172411  0.282710  0.205176
# 7   0.228232   0.170127  0.278922  0.196302
# 8   0.244252   0.163739  0.300489  0.184871
# 9   0.244131   0.179889  0.301254  0.194687
#        auc_train  auc_valid  acc_train  acc_valid  prec_train  prec_valid  \
# count  10.000000  10.000000  10.000000  10.000000   10.000000   10.000000
# mean    0.600123   0.560012   0.284506   0.216345    0.229018    0.206656
# std     0.004028   0.005296   0.017936   0.036126    0.010161    0.007511
# min     0.594601   0.553863   0.254800   0.163121    0.216966    0.196729
# 25%     0.597179   0.555010   0.273857   0.196154    0.220288    0.201967
# 50%     0.600603   0.560931   0.280987   0.205435    0.227865    0.206030
# 75%     0.602495   0.563098   0.302016   0.239140    0.235044    0.210986
# max     0.605734   0.569654   0.307566   0.275385    0.244252    0.217936
#
#        rec_train  rec_valid   f1_train   f1_valid
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.229018   0.172415   0.282463   0.191115
# std     0.010161   0.012557   0.012705   0.013431
# min     0.216966   0.152569   0.262353   0.170566
# 25%     0.220288   0.165336   0.277938   0.183310
# 50%     0.227865   0.174307   0.283469   0.189871
# 75%     0.235044   0.177485   0.286422   0.195898
# max     0.244252   0.196912   0.301254   0.217707

# %%
ax = opt_model_ori_tscv_scores.plot(figsize=(8,4))

# %%
ax = opt_model_ori_tscv_scores[['auc_train', 'auc_valid']].plot(figsize=(8,4))

# %%
ax = opt_model_ori_tscv_scores[['acc_train', 'acc_valid']].plot(figsize=(8,4), color=['#2ca02c', '#d62728'])

# %%
ax = opt_model_ori_tscv_scores[['prec_train', 'prec_valid']].plot(figsize=(8,4), color=['#9467bd', '#8c564b'])

# %%
ax = opt_model_ori_tscv_scores[['rec_train', 'rec_valid']].plot(figsize=(8,4), color=['#e377c2', '#8c564b'])

# %%
ax = opt_model_ori_tscv_scores[['f1_train', 'f1_valid']].plot(figsize=(8,4), color=['#bcbd22', '#17becf'])

# %% [markdown]
# ### Model Performance on Test Set

# %%
opt_model_ori_test_scores = performance_test_shifted(data_set, opt_model_ori, 'fam_target_ori')
opt_model_ori_test_scores = pd.DataFrame(opt_model_ori_test_scores)
display(opt_model_ori_test_scores)
display(opt_model_ori_test_scores.describe())
# Out:
#    auc_train  auc_test  acc_train  acc_test  prec_train  prec_test  rec_train  \
# 0   0.604645  0.561714   0.273621  0.235129    0.235305   0.203117   0.235305
# 1   0.600476  0.570338   0.269827  0.268474    0.226652   0.214735   0.226652
# 2   0.605116  0.558665   0.299118  0.190229    0.240562   0.204599   0.240562
# 3   0.596638  0.554534   0.272951  0.169200    0.220885   0.202110   0.220885
# 4   0.592664  0.553488   0.268923  0.177068    0.212048   0.200344   0.212048
# 5   0.597838  0.556090   0.287852  0.188796    0.224975   0.210358   0.224975
# 6   0.600511  0.560785   0.283759  0.196375    0.229934   0.215193   0.229934
# 7   0.601307  0.552094   0.290309  0.190496    0.232428   0.195193   0.232428
# 8   0.604628  0.560480   0.288577  0.209698    0.238526   0.206500   0.238526
# 9   0.602331  0.559446   0.302590  0.236785    0.235952   0.203390   0.235952
#
#    rec_test  f1_train   f1_test  \
# 0  0.175198  0.291440  0.192197
# 1  0.196694  0.278385  0.219802
# 2  0.181327  0.293827  0.185554
# 3  0.157255  0.277359  0.183968
# 4  0.151513  0.262409  0.167382
# 5  0.163822  0.274207  0.186672
# 6  0.166617  0.288054  0.201076
# 7  0.155768  0.287851  0.176303
# 8  0.164342  0.293700  0.183413
# 9  0.167542  0.292070  0.179504
#
#                                                                                                                                                                                                                                                                  ts_mean_true  \
# 0  fam_target_ori_clayton     0.030864
# fam_target_ori_frank       0.045455
# fam_target_ori_gaussian    0.212682
# fam_target_ori_gumbel      0.332772
# fam_target_ori_indep       0.072952
# fam_target_ori_joe         0.017957
# fam_target_ori_student     0.287318
# dtype: float64
# 1  fam_target_ori_clayton     0.015417
# fam_target_ori_frank       0.041999
# fam_target_ori_gaussian    0.143009
# fam_target_ori_gumbel      0.358320
# fam_target_ori_indep       0.050505
# fam_target_ori_joe         0.017544
# fam_target_ori_student     0.373206
# dtype: float64
# 2  fam_target_ori_clayton     0.027027
# fam_target_ori_frank       0.161123
# fam_target_ori_gaussian    0.306133
# fam_target_ori_gumbel      0.240644
# fam_target_ori_indep       0.092516
# fam_target_ori_joe         0.010395
# fam_target_ori_student     0.162162
# dtype: float64
# 3  fam_target_ori_clayton     0.054205
# fam_target_ori_frank       0.111449
# fam_target_ori_gaussian    0.235562
# fam_target_ori_gumbel      0.372847
# fam_target_ori_indep       0.110436
# fam_target_ori_joe         0.035968
# fam_target_ori_student     0.079534
# dtype: float64
# 4  fam_target_ori_clayton     0.061442
# fam_target_ori_frank       0.212869
# fam_target_ori_gaussian    0.164973
# fam_target_ori_gumbel      0.388002
# fam_target_ori_indep       0.096759
# fam_target_ori_joe         0.017417
# fam_target_ori_student     0.058539
# dtype: float64
# 5  fam_target_ori_clayton     0.026908
# fam_target_ori_frank       0.215704
# fam_target_ori_gaussian    0.235112
# fam_target_ori_gumbel      0.280988
# fam_target_ori_indep       0.109396
# fam_target_ori_joe         0.019850
# fam_target_ori_student     0.112042
# dtype: float64
# 6  fam_target_ori_clayton     0.025896
# fam_target_ori_frank       0.132067
# fam_target_ori_gaussian    0.153215
# fam_target_ori_gumbel      0.429003
# fam_target_ori_indep       0.090203
# fam_target_ori_joe         0.021148
# fam_target_ori_student     0.148468
# dtype: float64
# 7  fam_target_ori_clayton     0.045397
# fam_target_ori_frank       0.203224
# fam_target_ori_gaussian    0.302503
# fam_target_ori_gumbel      0.234196
# fam_target_ori_indep       0.170132
# fam_target_ori_joe         0.010607
# fam_target_ori_student     0.033941
# dtype: float64
# 8  fam_target_ori_clayton     0.054870
# fam_target_ori_frank       0.066780
# fam_target_ori_gaussian    0.169715
# fam_target_ori_gumbel      0.437686
# fam_target_ori_indep       0.113994
# fam_target_ori_joe         0.031476
# fam_target_ori_student     0.125479
# dtype: float64
# 9  fam_target_ori_clayton     0.048930
# fam_target_ori_frank       0.104849
# fam_target_ori_gaussian    0.232416
# fam_target_ori_gumbel      0.396680
# fam_target_ori_indep       0.115771
# fam_target_ori_joe         0.027523
# fam_target_ori_student     0.073831
# dtype: float64
#
#                                                                                                       ts_mean_estim
# 0  0    0.000000
# 1    0.028058
# 2    0.010662
# 3    0.071268
# 4    0.052750
# 5    0.000000
# 6    0.338945
# dtype: float64
# 1  0    0.000000
# 1    0.007974
# 2    0.052100
# 3    0.080808
# 4    0.049973
# 5    0.000000
# 6    0.342903
# dtype: float64
# 2  0    0.000000
# 1    0.009875
# 2    0.014553
# 3    0.160083
# 4    0.058212
# 5    0.000000
# 6    0.310811
# dtype: float64
# 3  0    0.000000
# 1    0.012665
# 2    0.061297
# 3    0.157548
# 4    0.064843
# 5    0.000000
# 6    0.131206
# dtype: float64
# 4  0    0.000000
# 1    0.001451
# 2    0.071118
# 3    0.199806
# 4    0.102080
# 5    0.000000
# 6    0.029511
# dtype: float64
# 5  0    0.000000
# 1    0.030878
# 2    0.022056
# 3    0.287605
# 4    0.099250
# 5    0.000000
# 6    0.018086
# dtype: float64
# 6  0    0.000000
# 1    0.030211
# 2    0.037980
# 3    0.209754
# 4    0.084592
# 5    0.000000
# 6    0.049633
# dtype: float64
# 7  0    0.000000
# 1    0.031396
# 2    0.022486
# 3    0.282138
# 4    0.106067
# 5    0.000000
# 6    0.030972
# dtype: float64
# 8  0    0.000000
# 1    0.048915
# 2    0.042110
# 3    0.198639
# 4    0.122926
# 5    0.000000
# 6    0.013611
# dtype: float64
# 9  0    0.000000
# 1    0.018785
# 2    0.026649
# 3    0.284404
# 4    0.132372
# 5    0.000000
# 6    0.005242
# dtype: float64
#        auc_train   auc_test  acc_train   acc_test  prec_train  prec_test  \
# count  10.000000  10.000000  10.000000  10.000000   10.000000  10.000000
# mean    0.600615   0.558763   0.283753   0.206225    0.229727   0.205554
# std     0.003983   0.005244   0.012052   0.031236    0.008786   0.006316
# min     0.592664   0.552094   0.268923   0.169200    0.212048   0.195193
# 25%     0.598498   0.554923   0.273119   0.189154    0.225394   0.202362
# 50%     0.600909   0.559056   0.285805   0.193436    0.231181   0.203994
# 75%     0.604054   0.560709   0.289876   0.228771    0.235790   0.209394
# max     0.605116   0.570338   0.302590   0.268474    0.240562   0.215193
#
#        rec_train   rec_test   f1_train    f1_test
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.229727   0.168008   0.283930   0.187587
# std     0.008786   0.013427   0.010435   0.014443
# min     0.212048   0.151513   0.262409   0.167382
# 25%     0.225394   0.158896   0.277616   0.180481
# 50%     0.231181   0.165480   0.287953   0.184761
# 75%     0.235790   0.173284   0.291913   0.190816
# max     0.240562   0.196694   0.293827   0.219802

# %%
ax = opt_model_ori_test_scores.plot(figsize=(9,4))

# %%
ax = opt_model_ori_test_scores[['auc_train', 'auc_test']].plot(figsize=(8,4))

# %%
ax = opt_model_ori_test_scores[['acc_train', 'acc_test']].plot(figsize=(8,4), color=['#2ca02c', '#d62728'])

# %%
ax = opt_model_ori_test_scores[['prec_train', 'prec_test']].plot(figsize=(8,4), color=['#9467bd', '#8c564b'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_ori_test_scores[['rec_train', 'rec_test']].plot(figsize=(8,4), color=['#e377c2', '#8c564b'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_ori_test_scores[['f1_train', 'f1_test']].plot(figsize=(8,4), color=['#bcbd22', '#17becf'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
opt_model_ori_test_scores[['ts_mean_true', 'ts_mean_estim']]
# Out:
#                                                                                                                                                                                                                                                                  ts_mean_true  \
# 0  fam_target_ori_clayton     0.030864
# fam_target_ori_frank       0.045455
# fam_target_ori_gaussian    0.212682
# fam_target_ori_gumbel      0.332772
# fam_target_ori_indep       0.072952
# fam_target_ori_joe         0.017957
# fam_target_ori_student     0.287318
# dtype: float64
# 1  fam_target_ori_clayton     0.015417
# fam_target_ori_frank       0.041999
# fam_target_ori_gaussian    0.143009
# fam_target_ori_gumbel      0.358320
# fam_target_ori_indep       0.050505
# fam_target_ori_joe         0.017544
# fam_target_ori_student     0.373206
# dtype: float64
# 2  fam_target_ori_clayton     0.027027
# fam_target_ori_frank       0.161123
# fam_target_ori_gaussian    0.306133
# fam_target_ori_gumbel      0.240644
# fam_target_ori_indep       0.092516
# fam_target_ori_joe         0.010395
# fam_target_ori_student     0.162162
# dtype: float64
# 3  fam_target_ori_clayton     0.054205
# fam_target_ori_frank       0.111449
# fam_target_ori_gaussian    0.235562
# fam_target_ori_gumbel      0.372847
# fam_target_ori_indep       0.110436
# fam_target_ori_joe         0.035968
# fam_target_ori_student     0.079534
# dtype: float64
# 4  fam_target_ori_clayton     0.061442
# fam_target_ori_frank       0.212869
# fam_target_ori_gaussian    0.164973
# fam_target_ori_gumbel      0.388002
# fam_target_ori_indep       0.096759
# fam_target_ori_joe         0.017417
# fam_target_ori_student     0.058539
# dtype: float64
# 5  fam_target_ori_clayton     0.026908
# fam_target_ori_frank       0.215704
# fam_target_ori_gaussian    0.235112
# fam_target_ori_gumbel      0.280988
# fam_target_ori_indep       0.109396
# fam_target_ori_joe         0.019850
# fam_target_ori_student     0.112042
# dtype: float64
# 6  fam_target_ori_clayton     0.025896
# fam_target_ori_frank       0.132067
# fam_target_ori_gaussian    0.153215
# fam_target_ori_gumbel      0.429003
# fam_target_ori_indep       0.090203
# fam_target_ori_joe         0.021148
# fam_target_ori_student     0.148468
# dtype: float64
# 7  fam_target_ori_clayton     0.045397
# fam_target_ori_frank       0.203224
# fam_target_ori_gaussian    0.302503
# fam_target_ori_gumbel      0.234196
# fam_target_ori_indep       0.170132
# fam_target_ori_joe         0.010607
# fam_target_ori_student     0.033941
# dtype: float64
# 8  fam_target_ori_clayton     0.054870
# fam_target_ori_frank       0.066780
# fam_target_ori_gaussian    0.169715
# fam_target_ori_gumbel      0.437686
# fam_target_ori_indep       0.113994
# fam_target_ori_joe         0.031476
# fam_target_ori_student     0.125479
# dtype: float64
# 9  fam_target_ori_clayton     0.048930
# fam_target_ori_frank       0.104849
# fam_target_ori_gaussian    0.232416
# fam_target_ori_gumbel      0.396680
# fam_target_ori_indep       0.115771
# fam_target_ori_joe         0.027523
# fam_target_ori_student     0.073831
# dtype: float64
#
#                                                                                                       ts_mean_estim
# 0  0    0.000000
# 1    0.028058
# 2    0.010662
# 3    0.071268
# 4    0.052750
# 5    0.000000
# 6    0.338945
# dtype: float64
# 1  0    0.000000
# 1    0.007974
# 2    0.052100
# 3    0.080808
# 4    0.049973
# 5    0.000000
# 6    0.342903
# dtype: float64
# 2  0    0.000000
# 1    0.009875
# 2    0.014553
# 3    0.160083
# 4    0.058212
# 5    0.000000
# 6    0.310811
# dtype: float64
# 3  0    0.000000
# 1    0.012665
# 2    0.061297
# 3    0.157548
# 4    0.064843
# 5    0.000000
# 6    0.131206
# dtype: float64
# 4  0    0.000000
# 1    0.001451
# 2    0.071118
# 3    0.199806
# 4    0.102080
# 5    0.000000
# 6    0.029511
# dtype: float64
# 5  0    0.000000
# 1    0.030878
# 2    0.022056
# 3    0.287605
# 4    0.099250
# 5    0.000000
# 6    0.018086
# dtype: float64
# 6  0    0.000000
# 1    0.030211
# 2    0.037980
# 3    0.209754
# 4    0.084592
# 5    0.000000
# 6    0.049633
# dtype: float64
# 7  0    0.000000
# 1    0.031396
# 2    0.022486
# 3    0.282138
# 4    0.106067
# 5    0.000000
# 6    0.030972
# dtype: float64
# 8  0    0.000000
# 1    0.048915
# 2    0.042110
# 3    0.198639
# 4    0.122926
# 5    0.000000
# 6    0.013611
# dtype: float64
# 9  0    0.000000
# 1    0.018785
# 2    0.026649
# 3    0.284404
# 4    0.132372
# 5    0.000000
# 6    0.005242
# dtype: float64

# %% [markdown]
# ### Data for Storage

# %%
results_ori = {'Model': [opt_model_ori],
            'fc_horizon': 0,
            'vif': [vif],
            'auc_tscv_t': [opt_model_ori_tscv_scores.auc_train.mean()],
            'auc_tscv_v': [opt_model_ori_tscv_scores.auc_valid.mean()],
            'auc_train': [opt_model_ori_test_scores.auc_train.mean()],
            'auc_test': [opt_model_ori_test_scores.auc_test.mean()],
               
            'acc_tscv_t': [opt_model_ori_tscv_scores.acc_train.mean()],
            'acc_tscv_v': [opt_model_ori_tscv_scores.acc_valid.mean()],
            'acc_train': [opt_model_ori_test_scores.acc_train.mean()],
            'acc_test': [opt_model_ori_test_scores.acc_test.mean()],
               
            'prec_tscv_t': [opt_model_ori_tscv_scores.prec_train.mean()],
            'prec_tscv_v': [opt_model_ori_tscv_scores.prec_valid.mean()],
            'prec_train': [opt_model_ori_test_scores.prec_train.mean()],
            'prec_test': [opt_model_ori_test_scores.prec_test.mean()],
               
            'rec_tscv_t': [opt_model_ori_tscv_scores.rec_train.mean()],
            'rec_tscv_v': [opt_model_ori_tscv_scores.rec_valid.mean()],
            'rec_train': [opt_model_ori_test_scores.rec_train.mean()],
            'rec_test': [opt_model_ori_test_scores.rec_test.mean()],
               
            'f1_tscv_t': [opt_model_ori_tscv_scores.f1_train.mean()],
            'f1_tscv_v': [opt_model_ori_tscv_scores.f1_valid.mean()],
            'f1_train': [opt_model_ori_test_scores.f1_train.mean()],
            'f1_test': [opt_model_ori_test_scores.f1_test.mean()],
               
            'opt_model': [opt_model_ori.get_params()],
#             'ts_mean_true': opt_model_ori_test_scores.ts_mean_true,
#             'ts_mean_estim': opt_model_ori_test_scores.ts_mean_estim
              }

# %% [markdown]
# ## ----------------------------------------------------------
# ## Predicted Target Model (one year forecast horizon)
# ### Time Series Cross Validation on Default Model

# %%
default_model_scores_hor = cross_validation (data_set, default_model, 'fam_target_hor')
pd.DataFrame(default_model_scores_hor).describe()
# Out:
#        auc_train  auc_valid  acc_train  acc_valid  prec_train  prec_valid  \
# count       10.0  10.000000       10.0  10.000000        10.0   10.000000
# mean         1.0   0.552258        1.0   0.290711         1.0    0.177455
# std          0.0   0.008129        0.0   0.023587         0.0    0.005282
# min          1.0   0.543748        1.0   0.264753         1.0    0.169930
# 25%          1.0   0.545501        1.0   0.272646         1.0    0.175407
# 50%          1.0   0.551201        1.0   0.290263         1.0    0.176442
# 75%          1.0   0.556287        1.0   0.296925         1.0    0.178802
# max          1.0   0.570014        1.0   0.344557         1.0    0.190062
#
#        rec_train  rec_valid  f1_train   f1_valid
# count       10.0  10.000000      10.0  10.000000
# mean         1.0   0.234588       1.0   0.224545
# std          0.0   0.014225       0.0   0.010624
# min          1.0   0.219943       1.0   0.213086
# 25%          1.0   0.222775       1.0   0.216893
# 50%          1.0   0.233333       1.0   0.221741
# 75%          1.0   0.240905       1.0   0.228583
# max          1.0   0.266022       1.0   0.244494

# %%
ax = pd.DataFrame(default_model_scores_hor).plot(figsize=(8,4))

# %% [markdown]
# ### Hyperparameter Optimization with Time Series Cross Validation
# - Bayesian optimization
# - https://scikit-optimize.github.io/stable/auto_examples/bayesian-optimization.html

# %%
# objective function to minimize
def objective(params):
    max_depth, min_samples_split, min_samples_leaf = params
    model = ml_algorithm(max_depth=int(max_depth), min_samples_split=int(min_samples_split), min_samples_leaf=int(min_samples_leaf), random_state=23)
    scores = cross_validation(data_set, model, 'fam_target_hor')
    return -np.mean(scores['auc_valid'])

# perform the optimization
result = gp_minimize(objective, space, n_calls=100, n_random_starts=20, acq_func='EI', acq_optimizer='lbfgs', random_state=23, n_jobs=-1)

# optimal point and function value
print('Optimal point:', result.x)
print('Function value at optimal point:', result.fun)
ax = pd.DataFrame(result.func_vals).plot(figsize=(12,4))
# Out:
# Optimal point: [27, 5, 1]
# Function value at optimal point: -0.5491333759766714

# %% [markdown]
# ### Time Series Cross Validation on Optimal Model

# %%
# ---------------- config opt model -----------------
opt_model_hor = ml_algorithm(max_depth=27, min_samples_split=5, min_samples_leaf=1, random_state=23)

# %%
opt_model_hor_tscv_scores = cross_validation(data_set, opt_model_hor, 'fam_target_hor')
opt_model_hor_tscv_scores = pd.DataFrame(opt_model_hor_tscv_scores)
display(opt_model_hor_tscv_scores)
display(opt_model_hor_tscv_scores.describe())
# Out:
#    auc_train  auc_valid  acc_train  acc_valid  prec_train  prec_valid  \
# 0   0.894851   0.549368   0.849980   0.278822    0.794924    0.174941
# 1   0.895707   0.560485   0.861085   0.319304    0.796303    0.172617
# 2   0.899821   0.535975   0.876726   0.239766    0.804958    0.165997
# 3   0.888200   0.548599   0.836086   0.248960    0.781737    0.183196
# 4   0.890791   0.544027   0.857668   0.250253    0.787176    0.175588
# 5   0.894993   0.548845   0.866071   0.258829    0.795396    0.180843
# 6   0.887579   0.548522   0.847569   0.258050    0.780594    0.178506
# 7   0.898363   0.549315   0.863467   0.251187    0.801953    0.177338
# 8   0.897511   0.555006   0.865258   0.287230    0.800686    0.182301
# 9   0.894345   0.551192   0.860161   0.291791    0.795438    0.180037
#
#    rec_train  rec_valid  f1_train  f1_valid
# 0   0.794924   0.216631  0.866460  0.217478
# 1   0.796303   0.233870  0.865406  0.231425
# 2   0.804958   0.194377  0.870036  0.192722
# 3   0.781737   0.210870  0.855965  0.217523
# 4   0.787176   0.205536  0.859691  0.205207
# 5   0.795396   0.213762  0.864321  0.224084
# 6   0.780594   0.210404  0.854796  0.219438
# 7   0.801953   0.213646  0.869655  0.211183
# 8   0.800686   0.222401  0.868230  0.221184
# 9   0.795438   0.218599  0.862347  0.224542
#        auc_train  auc_valid  acc_train  acc_valid  prec_train  prec_valid  \
# count  10.000000  10.000000  10.000000  10.000000   10.000000   10.000000
# mean    0.894216   0.549133   0.858407   0.268419    0.793917    0.177136
# std     0.004146   0.006391   0.011374   0.024997    0.008265    0.005155
# min     0.887579   0.535975   0.836086   0.239766    0.780594    0.165997
# 25%     0.891679   0.548541   0.851902   0.250487    0.789113    0.175103
# 50%     0.894922   0.549080   0.860623   0.258440    0.795417    0.177922
# 75%     0.897060   0.550736   0.864810   0.285128    0.799590    0.180642
# max     0.899821   0.560485   0.876726   0.319304    0.804958    0.183196
#
#        rec_train  rec_valid   f1_train   f1_valid
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.793917   0.214010   0.863691   0.216478
# std     0.008265   0.010398   0.005417   0.011049
# min     0.780594   0.194377   0.854796   0.192722
# 25%     0.789113   0.210520   0.860355   0.212756
# 50%     0.795417   0.213704   0.864863   0.218480
# 75%     0.799590   0.218107   0.867788   0.223359
# max     0.804958   0.233870   0.870036   0.231425

# %%
ax = opt_model_hor_tscv_scores.plot(figsize=(9,5))

# %%
ax = opt_model_hor_tscv_scores[['auc_train', 'auc_valid']].plot(figsize=(8,4))
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_hor_tscv_scores[['acc_train', 'acc_valid']].plot(figsize=(8,4), color=['#2ca02c', '#d62728'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_hor_tscv_scores[['prec_train', 'prec_valid']].plot(figsize=(8,4), color=['#9467bd', '#8c564b'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_hor_tscv_scores[['rec_train', 'rec_valid']].plot(figsize=(8,4), color=['#e377c2', '#8c564b'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_hor_tscv_scores[['f1_train', 'f1_valid']].plot(figsize=(8,4), color=['#bcbd22', '#17becf'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %% [markdown]
# ### Model Performance on Test Set

# %%
opt_model_hor_test_scores = performance_test_shifted(data_set, opt_model_hor, 'fam_target_hor')
opt_model_hor_test_scores = pd.DataFrame(opt_model_hor_test_scores)
display(opt_model_hor_test_scores)
display(opt_model_hor_test_scores.describe())
# Out:
#    auc_train  auc_test  acc_train  acc_test  prec_train  prec_test  rec_train  \
# 0   0.896461  0.555581   0.863804  0.310325    0.798092   0.172619   0.798092
# 1   0.899652  0.541480   0.870757  0.253589    0.804793   0.169678   0.804793
# 2   0.897138  0.549992   0.864902  0.259875    0.799737   0.180405   0.799737
# 3   0.882633  0.548308   0.837418  0.265451    0.771849   0.172781   0.771849
# 4   0.890941  0.552623   0.852831  0.259797    0.788976   0.180588   0.788976
# 5   0.896336  0.549818   0.864281  0.277900    0.797885   0.178821   0.797885
# 6   0.895313  0.545597   0.859179  0.250755    0.796243   0.180051   0.796243
# 7   0.899386  0.550671   0.866182  0.279593    0.804012   0.174358   0.804012
# 8   0.897047  0.538755   0.860336  0.279881    0.800476   0.170703   0.800476
# 9   0.886039  0.539076   0.850634  0.185671    0.779145   0.149913   0.779145
#
#    rec_test  f1_train   f1_test  \
# 0  0.226625  0.865084  0.217367
# 1  0.205597  0.870293  0.201093
# 2  0.218070  0.866768  0.220328
# 3  0.212092  0.848588  0.212621
# 4  0.220973  0.860001  0.233830
# 5  0.216071  0.866806  0.223635
# 6  0.204424  0.865314  0.203030
# 7  0.215535  0.870046  0.216263
# 8  0.195159  0.867009  0.204649
# 9  0.196995  0.851237  0.113400
#
#                                                                                                                                                                                                                                                                  ts_mean_true  \
# 0  fam_target_hor_clayton     0.015152
# fam_target_hor_frank       0.042088
# fam_target_hor_gaussian    0.143098
# fam_target_hor_gumbel      0.356341
# fam_target_hor_indep       0.049944
# fam_target_hor_joe         0.016274
# fam_target_hor_student     0.377104
# dtype: float64
# 1  fam_target_hor_clayton     0.022860
# fam_target_hor_frank       0.162148
# fam_target_hor_gaussian    0.307283
# fam_target_hor_gumbel      0.243488
# fam_target_hor_indep       0.086656
# fam_target_hor_joe         0.010633
# fam_target_hor_student     0.166932
# dtype: float64
# 2  fam_target_hor_clayton     0.051455
# fam_target_hor_frank       0.111746
# fam_target_hor_gaussian    0.235447
# fam_target_hor_gumbel      0.373181
# fam_target_hor_indep       0.102911
# fam_target_hor_joe         0.040021
# fam_target_hor_student     0.085239
# dtype: float64
# 3  fam_target_hor_clayton     0.057244
# fam_target_hor_frank       0.211246
# fam_target_hor_gaussian    0.165147
# fam_target_hor_gumbel      0.397670
# fam_target_hor_indep       0.093212
# fam_target_hor_joe         0.017224
# fam_target_hor_student     0.058257
# dtype: float64
# 4  fam_target_hor_clayton     0.025157
# fam_target_hor_frank       0.210450
# fam_target_hor_gaussian    0.241413
# fam_target_hor_gumbel      0.283986
# fam_target_hor_indep       0.100629
# fam_target_hor_joe         0.021771
# fam_target_hor_student     0.116594
# dtype: float64
# 5  fam_target_hor_clayton     0.027790
# fam_target_hor_frank       0.132333
# fam_target_hor_gaussian    0.154830
# fam_target_hor_gumbel      0.432289
# fam_target_hor_indep       0.084693
# fam_target_hor_joe         0.020732
# fam_target_hor_student     0.147331
# dtype: float64
# 6  fam_target_hor_clayton     0.047044
# fam_target_hor_frank       0.205006
# fam_target_hor_gaussian    0.300388
# fam_target_hor_gumbel      0.247734
# fam_target_hor_indep       0.156237
# fam_target_hor_joe         0.008632
# fam_target_hor_student     0.034959
# dtype: float64
# 7  fam_target_hor_clayton     0.052185
# fam_target_hor_frank       0.069156
# fam_target_hor_gaussian    0.165040
# fam_target_hor_gumbel      0.440815
# fam_target_hor_indep       0.108613
# fam_target_hor_joe         0.033941
# fam_target_hor_student     0.130250
# dtype: float64
# 8  fam_target_hor_clayton     0.051042
# fam_target_hor_frank       0.107188
# fam_target_hor_gaussian    0.227988
# fam_target_hor_gumbel      0.399830
# fam_target_hor_indep       0.113569
# fam_target_hor_joe         0.027222
# fam_target_hor_student     0.073160
# dtype: float64
# 9  fam_target_hor_clayton     0.013106
# fam_target_hor_frank       0.007864
# fam_target_hor_gaussian    0.029270
# fam_target_hor_gumbel      0.363478
# fam_target_hor_indep       0.015291
# fam_target_hor_joe         0.083006
# fam_target_hor_student     0.487986
# dtype: float64
#
#                                                                                                       ts_mean_estim
# 0  0    0.014029
# 1    0.076319
# 2    0.175084
# 3    0.251964
# 4    0.068462
# 5    0.014029
# 6    0.308081
# dtype: float64
# 1  0    0.015949
# 1    0.057416
# 2    0.153110
# 3    0.269537
# 4    0.058480
# 5    0.008506
# 6    0.372142
# dtype: float64
# 2  0    0.015073
# 1    0.093555
# 2    0.216216
# 3    0.257796
# 4    0.068087
# 5    0.009875
# 6    0.253119
# dtype: float64
# 3  0    0.013678
# 1    0.096758
# 2    0.201114
# 3    0.321682
# 4    0.075988
# 5    0.012665
# 6    0.168186
# dtype: float64
# 4  0    0.019836
# 1    0.123367
# 2    0.152395
# 3    0.350750
# 4    0.084180
# 5    0.014998
# 6    0.148524
# dtype: float64
# 5  0    0.026908
# 1    0.151742
# 2    0.168946
# 3    0.317600
# 4    0.083370
# 5    0.017203
# 6    0.132775
# dtype: float64
# 6  0    0.018127
# 1    0.122572
# 2    0.146310
# 3    0.348295
# 4    0.077687
# 5    0.012085
# 6    0.160984
# dtype: float64
# 7  0    0.027577
# 1    0.144675
# 2    0.212983
# 3    0.300382
# 4    0.103521
# 5    0.016971
# 6    0.091218
# dtype: float64
# 8  0    0.033603
# 1    0.108890
# 2    0.189281
# 3    0.364526
# 4    0.099957
# 5    0.023820
# 6    0.078690
# dtype: float64
# 9  0    0.038008
# 1    0.106597
# 2    0.191787
# 3    0.335518
# 4    0.114024
# 5    0.016601
# 6    0.064220
# dtype: float64
#        auc_train   auc_test  acc_train   acc_test  prec_train  prec_test  \
# count  10.000000  10.000000  10.000000  10.000000   10.000000  10.000000
# mean    0.894095   0.547190   0.859032   0.262284    0.794121   0.172992
# std     0.005727   0.005775   0.009725   0.032078    0.010878   0.009113
# min     0.882633   0.538755   0.837418   0.185671    0.771849   0.149913
# 25%     0.892034   0.542509   0.854418   0.255141    0.790793   0.171182
# 50%     0.896399   0.549063   0.862070   0.262663    0.797988   0.173570
# 75%     0.897115   0.550501   0.864747   0.279170    0.800292   0.179743
# max     0.899652   0.555581   0.870757   0.310325    0.804793   0.180588
#
#        rec_train   rec_test   f1_train    f1_test
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.794121   0.211154   0.863115   0.204622
# std     0.010878   0.010330   0.007544   0.033598
# min     0.771849   0.195159   0.848588   0.113400
# 25%     0.790793   0.204717   0.861272   0.203435
# 50%     0.797988   0.213813   0.866041   0.214442
# 75%     0.800292   0.217570   0.866959   0.219588
# max     0.804793   0.226625   0.870293   0.233830

# %%
ax = opt_model_hor_test_scores[['auc_train', 'auc_test']].plot(figsize=(8,4))
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_hor_test_scores[['acc_train', 'acc_test']].plot(figsize=(8,4), color=['#2ca02c', '#d62728'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_hor_test_scores[['prec_train', 'prec_test']].plot(figsize=(8,4), color=['#9467bd', '#8c564b'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_hor_test_scores[['rec_train', 'rec_test']].plot(figsize=(8,4), color=['#e377c2', '#8c564b'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_hor_test_scores[['f1_train', 'f1_test']].plot(figsize=(8,4), color=['#bcbd22', '#17becf'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_hor_test_scores[['ts_mean_true', 'ts_mean_estim']]

# %% [markdown]
# ### Data for Storage

# %%
results_hor = {'Model': [opt_model_ori],
            'fc_horizon': 1,
            'vif': [vif],
            'auc_tscv_t': [opt_model_hor_tscv_scores.auc_train.mean()],
            'auc_tscv_v': [opt_model_hor_tscv_scores.auc_valid.mean()],
            'auc_train': [opt_model_hor_test_scores.auc_train.mean()],
            'auc_test': [opt_model_hor_test_scores.auc_test.mean()],
               
            'acc_tscv_t': [opt_model_hor_tscv_scores.acc_train.mean()],
            'acc_tscv_v': [opt_model_hor_tscv_scores.acc_valid.mean()],
            'acc_train': [opt_model_hor_test_scores.acc_train.mean()],
            'acc_test': [opt_model_hor_test_scores.acc_test.mean()],
               
            'prec_tscv_t': [opt_model_hor_tscv_scores.prec_train.mean()],
            'prec_tscv_v': [opt_model_hor_tscv_scores.prec_valid.mean()],
            'prec_train': [opt_model_hor_test_scores.prec_train.mean()],
            'prec_test': [opt_model_hor_test_scores.prec_test.mean()],
               
            'rec_tscv_t': [opt_model_hor_tscv_scores.rec_train.mean()],
            'rec_tscv_v': [opt_model_hor_tscv_scores.rec_valid.mean()],
            'rec_train': [opt_model_hor_test_scores.rec_train.mean()],
            'rec_test': [opt_model_hor_test_scores.rec_test.mean()],
               
            'f1_tscv_t': [opt_model_hor_tscv_scores.f1_train.mean()],
            'f1_tscv_v': [opt_model_hor_tscv_scores.f1_valid.mean()],
            'f1_train': [opt_model_hor_test_scores.f1_train.mean()],
            'f1_test': [opt_model_hor_test_scores.f1_test.mean()],
               
            'opt_model': [opt_model_ori.get_params()],
#             'ts_mean_true': opt_model_ori_test_scores.ts_mean_true,
#             'ts_mean_estim': opt_model_ori_test_scores.ts_mean_estim
              }

# %% [markdown]
# ## Safe to Excel

# %%
results = pd.concat([pd.DataFrame(results_ori), pd.DataFrame(results_hor)])

display(results)

storage_name = filename + '_' + vif + '_' + str(datetime.today().day) + '.xlsx'

pd.DataFrame(results).to_excel(path + 'artifacts' + slash + storage_name, index=None)
# Out:
#                                                                         Model  \
# 0  DecisionTreeClassifier(max_depth=48, min_samples_leaf=37, random_state=23)
# 0  DecisionTreeClassifier(max_depth=48, min_samples_leaf=37, random_state=23)
#
#    fc_horizon  vif  auc_tscv_t  auc_tscv_v  auc_train  auc_test  acc_tscv_t  \
# 0           0  all    0.600123    0.560012   0.600615  0.558763    0.284506
# 0           1  all    0.894216    0.549133   0.894095  0.547190    0.858407
#
#    acc_tscv_v  acc_train  acc_test  prec_tscv_t  prec_tscv_v  prec_train  \
# 0    0.216345   0.283753  0.206225     0.229018     0.206656    0.229727
# 0    0.268419   0.859032  0.262284     0.793917     0.177136    0.794121
#
#    prec_test  rec_tscv_t  rec_tscv_v  rec_train  rec_test  f1_tscv_t  \
# 0   0.205554    0.229018    0.172415   0.229727  0.168008   0.282463
# 0   0.172992    0.793917    0.214010   0.794121  0.211154   0.863691
#
#    f1_tscv_v  f1_train   f1_test  \
# 0   0.191115  0.283930  0.187587
# 0   0.216478  0.863115  0.204622
#
#                                                                                                                                                                                                                                                                              opt_model
# 0  {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 48, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 37, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': 23, 'splitter': 'best'}
# 0  {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 48, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 37, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': 23, 'splitter': 'best'}
