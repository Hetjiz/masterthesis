# %% [markdown]
# # K Neares Neighbor (tau) [all]
# Regression based on k-nearest neighbors.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsRegressor.html
#
# KNeighborsRegressor()
#
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 5,
#  'p': 2,
#  'weights': 'uniform'}
#
# **_bayesian hyperparameter tuning_**

# %%
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pathlib
import platform
import seaborn as sns
from sklearn import linear_model
from sklearn import tree
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from skopt import gp_minimize, space
from skopt.space import Real, Integer
import sys

from validation import cross_validation
from validation import performance_test_shifted

date_format = '%Y-%m-%d'

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.max_colwidth = None

# %%
# config 'all', 'vif_5' or 'vif_10'
vif = 'all'

# config model
ml_algorithm = KNeighborsRegressor
filename = 'single-model_tau_knn'

# %%
my_os = platform.system()
print('OS in my system: ',my_os)

if my_os == 'Windows':
    path = str(pathlib.Path().absolute()) + '\\'
    slash = '\\'
else:
    path = str(pathlib.Path().absolute()) + '/'
    slash = '/'

path_3 = path.replace('4_modelling', '3_data_pre-processing')
# Out:
# OS in my system:  Linux

# %% [markdown]
# ## Load Data

# %%
data_set = pd.read_csv(path_3 + 'data_artifacts' + slash + 'data_set_e_spx_3-' + vif + '.csv', index_col=0)

# %% [markdown]
# ## Original Target Model (no forecast horizon)
# ### Time Series Cross Validation on Default Model

# %%
default_model = ml_algorithm()
default_model.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 5,
#  'p': 2,
#  'weights': 'uniform'}

# %%
default_model_scores_ori = cross_validation (data_set, default_model, 'tau_target_ori')
pd.DataFrame(default_model_scores_ori).describe()
# Out:
#        mse_train  mse_valid  mae_train  mae_valid   r2_train   r2_valid
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.006693   0.013849   0.063948   0.093989   0.759794   0.382844
# std     0.000487   0.004803   0.002606   0.019043   0.012829   0.293256
# min     0.005968   0.008569   0.060231   0.071465   0.743424  -0.403273
# 25%     0.006323   0.010269   0.062346   0.080237   0.751010   0.392167
# 50%     0.006646   0.012350   0.063439   0.088823   0.757705   0.445239
# 75%     0.007132   0.018055   0.066324   0.111466   0.763150   0.536812
# max     0.007362   0.021679   0.067853   0.122970   0.782867   0.606974

# %%
ax = pd.DataFrame(default_model_scores_ori).plot(figsize=(8,4))

# %% [markdown]
# ### Hyperparameter Optimization with Time Series Cross Validation
# - Bayesian optimization
# - https://scikit-optimize.github.io/stable/auto_examples/bayesian-optimization.html

# %%
# search space for the hyperparameters
space = [Integer(1, 30, name='n_neighbors'),
         Integer(1, 50, name='leaf_size'),
         Integer(1, 2, name='p')]

# %%
# objective function to minimize
def objective(params):
    n_neighbors, leaf_size, p = params
    model = ml_algorithm(n_neighbors=int(n_neighbors), leaf_size=int(leaf_size), p=int(p))
    scores = cross_validation(data_set, model, 'tau_target_ori')
    return np.mean(scores['mse_valid'])

# perform the optimization
result = gp_minimize(objective, space, n_calls=100, n_random_starts=20, acq_func='EI', acq_optimizer='auto', random_state=23, n_jobs=-1)

# optimal point and function value
print('Optimal point:', result.x)
print('Function value at optimal point:', result.fun)
ax = pd.DataFrame(result.func_vals).plot(figsize=(12,4))
# Out:
# Optimal point: [3, 1, 1]
# Function value at optimal point: 0.012161359800480265

# %% [markdown]
# ### Time Series Cross Validation on Optimal Model

# %%
# ---------------- config opt model -----------------
opt_model_ori = ml_algorithm(n_neighbors=3, leaf_size=1, p=1)

# %%
opt_model_ori_tscv_scores = cross_validation(data_set, opt_model_ori, 'tau_target_ori')
opt_model_ori_tscv_scores = pd.DataFrame(opt_model_ori_tscv_scores)
display(opt_model_ori_tscv_scores)
display(opt_model_ori_tscv_scores.describe())
# Out:
#    mse_train  mse_valid  mae_train  mae_valid  r2_train  r2_valid
# 0   0.004143   0.019138   0.049146   0.112022  0.830687  0.373672
# 1   0.004180   0.010371   0.049222   0.079420  0.843776  0.614990
# 2   0.004016   0.016174   0.048357   0.105102  0.853713  0.512134
# 3   0.004470   0.013032   0.051231   0.093456  0.850542  0.503933
# 4   0.004777   0.012448   0.053974   0.090711  0.839496  0.432317
# 5   0.004991   0.010078   0.055764   0.079242  0.829280  0.475640
# 6   0.004497   0.008199   0.052450   0.070173  0.841931  0.658731
# 7   0.004085   0.007032   0.049527   0.064926  0.856666  0.658368
# 8   0.003856   0.017016   0.047900   0.107932  0.859716 -0.206911
# 9   0.004210   0.008126   0.050422   0.070252  0.842759  0.565885
#        mse_train  mse_valid  mae_train  mae_valid   r2_train   r2_valid
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.004323   0.012161   0.050799   0.087323   0.844857   0.458876
# std     0.000356   0.004150   0.002560   0.017045   0.010313   0.252091
# min     0.003856   0.007032   0.047900   0.064926   0.829280  -0.206911
# 25%     0.004100   0.008669   0.049165   0.072499   0.840105   0.443148
# 50%     0.004195   0.011410   0.049975   0.085066   0.843268   0.508034
# 75%     0.004490   0.015389   0.052145   0.102190   0.852920   0.602714
# max     0.004991   0.019138   0.055764   0.112022   0.859716   0.658731

# %%
ax = opt_model_ori_tscv_scores[['mse_train', 'mse_valid', 'mae_train', 'mae_valid', 'r2_train', 'r2_valid']].plot(figsize=(8,4))

# %%
ax = opt_model_ori_tscv_scores[['mse_train', 'mse_valid']].plot(figsize=(8,4))

# %%
ax = opt_model_ori_tscv_scores[['mae_train', 'mae_valid']].plot(figsize=(8,4), color=['#2ca02c', '#d62728'])

# %%
ax = opt_model_ori_tscv_scores[['r2_train', 'r2_valid']].plot(figsize=(8,4), color=['#9467bd', '#8c564b'])

# %% [markdown]
# ### Model Performance on Test Set

# %%
opt_model_ori_test_scores = performance_test_shifted(data_set, opt_model_ori, 'tau_target_ori')
opt_model_ori_test_scores = pd.DataFrame(opt_model_ori_test_scores)
display(opt_model_ori_test_scores)
display(opt_model_ori_test_scores.describe())
# Out:
#    mse_train  mse_test  mae_train  mae_test  r2_train   r2_test  ts_mean_true  \
# 0   0.004440  0.010511   0.050788  0.079944  0.833290  0.609811      0.366445
# 1   0.003930  0.016324   0.047911  0.105866  0.856244  0.507602      0.425448
# 2   0.004362  0.012874   0.050547  0.092533  0.853699  0.509949      0.330819
# 3   0.004698  0.012299   0.053389  0.089759  0.840214  0.439111      0.286654
# 4   0.004739  0.009897   0.053980  0.078657  0.837038  0.485049      0.281294
# 5   0.004646  0.008087   0.053090  0.069667  0.835955  0.663391      0.288558
# 6   0.004162  0.006891   0.050185  0.064345  0.852301  0.665199      0.291026
# 7   0.003834  0.017097   0.047809  0.108257  0.861467 -0.212666      0.199579
# 8   0.004308  0.008300   0.050832  0.071222  0.843856  0.556584      0.245124
# 9   0.003985  0.006593   0.049104  0.062125  0.847624  0.683155      0.245513
#
#    ts_mean_estim
# 0       0.327321
# 1       0.346584
# 2       0.374640
# 3       0.358266
# 4       0.330610
# 5       0.313070
# 6       0.306525
# 7       0.298649
# 8       0.268774
# 9       0.256196
#        mse_train   mse_test  mae_train   mae_test   r2_train    r2_test  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.004310   0.010887   0.050764   0.082238   0.846169   0.490718
# std     0.000327   0.003714   0.002177   0.016398   0.009582   0.261175
# min     0.003834   0.006593   0.047809   0.062125   0.833290  -0.212666
# 25%     0.004029   0.008140   0.049374   0.070056   0.837832   0.490687
# 50%     0.004335   0.010204   0.050668   0.079300   0.845740   0.533267
# 75%     0.004595   0.012730   0.052526   0.091840   0.853350   0.649996
# max     0.004739   0.017097   0.053980   0.108257   0.861467   0.683155
#
#        ts_mean_true  ts_mean_estim
# count     10.000000      10.000000
# mean       0.296046       0.318064
# std        0.064764       0.037514
# min        0.199579       0.256196
# 25%        0.254458       0.300618
# 50%        0.287606       0.320195
# 75%        0.320871       0.342591
# max        0.425448       0.374640

# %%
ax = opt_model_ori_test_scores.plot(figsize=(8,4))

# %%
ax = opt_model_ori_test_scores[['mse_train', 'mse_test']].plot(figsize=(8,4))

# %%
ax = opt_model_ori_test_scores[['mae_train', 'mae_test']].plot(figsize=(8,4), color=['#2ca02c', '#d62728'])

# %%
ax = opt_model_ori_test_scores[['r2_train', 'r2_test']].plot(figsize=(8,4), color=['#9467bd', '#8c564b'])

# %%
ax = opt_model_ori_test_scores[['ts_mean_true', 'ts_mean_estim']].plot(figsize=(8,4), color=['#e377c2', '#8c564b'])
plt.ylim([0.2,0.45])
# Out:
# (0.2, 0.45)

# %% [markdown]
# ### Data for Storage

# %%
results_ori = {'Model': [opt_model_ori],
            'fc_horizon': 0,
            'vif': [vif],
            'mse_tscv_t': [opt_model_ori_tscv_scores.mse_train.mean()],
            'mse_tscv_v': [opt_model_ori_tscv_scores.mse_valid.mean()],
            'mse_train': [opt_model_ori_test_scores.mse_train.mean()],
            'mse_test': [opt_model_ori_test_scores.mse_test.mean()],
               
            'mae_tscv_t': [opt_model_ori_tscv_scores.mae_train.mean()],
            'mae_tscv_v': [opt_model_ori_tscv_scores.mae_valid.mean()],
            'mae_train': [opt_model_ori_test_scores.mae_train.mean()],
            'mae_test': [opt_model_ori_test_scores.mae_test.mean()],
               
            'r2_tscv_t': [opt_model_ori_tscv_scores.r2_train.mean()],
            'r2_tscv_v': [opt_model_ori_tscv_scores.r2_valid.mean()],
            'r2_train': [opt_model_ori_test_scores.r2_train.mean()],
            'r2_test': [opt_model_ori_test_scores.r2_test.mean()],
               
            'opt_model': [opt_model_ori.get_params()],
            'ts_mean_true': opt_model_ori_test_scores.ts_mean_true.mean(),
            'ts_mean_estim': opt_model_ori_test_scores.ts_mean_estim.mean(),
              }

# %% [markdown]
# ## ----------------------------------------------------------
# ## Predicted Target Model (one year forecast horizon)
# ### Time Series Cross Validation on Default Model

# %%
default_model_scores_hor = cross_validation (data_set, default_model, 'tau_target_hor')
pd.DataFrame(default_model_scores_hor).describe()
# Out:
#        mse_train  mse_valid  mae_train  mae_valid   r2_train   r2_valid
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.006731   0.012945   0.064303   0.090156   0.755581   0.387268
# std     0.000477   0.004692   0.002556   0.019129   0.011458   0.328304
# min     0.006038   0.008189   0.060667   0.068676   0.743698  -0.515257
# 25%     0.006380   0.009677   0.062299   0.076554   0.747139   0.386421
# 50%     0.006645   0.011947   0.063801   0.087334   0.753910   0.472071
# 75%     0.007200   0.013676   0.066400   0.093944   0.757575   0.549326
# max     0.007374   0.021313   0.067851   0.123414   0.776126   0.603063

# %%
ax = pd.DataFrame(default_model_scores_hor).plot(figsize=(8,4))

# %% [markdown]
# ### Hyperparameter Optimization with Time Series Cross Validation
# - Bayesian optimization
# - https://scikit-optimize.github.io/stable/auto_examples/bayesian-optimization.html

# %%
# objective function to minimize
def objective(params):
    n_neighbors, leaf_size, p = params
    model = ml_algorithm(n_neighbors=int(n_neighbors), leaf_size=int(leaf_size), p=int(p))
    scores = cross_validation(data_set, model, 'tau_target_hor')
    return np.mean(scores['mse_valid'])

# perform the optimization
result = gp_minimize(objective, space, n_calls=100, n_random_starts=20, acq_func='EI', acq_optimizer='auto', random_state=23, n_jobs=-1)

# optimal point and function value
print('Optimal point:', result.x)
print('Function value at optimal point:', result.fun)
ax = pd.DataFrame(result.func_vals).plot(figsize=(12,4))
# Out:
# Optimal point: [4, 36, 1]
# Function value at optimal point: 0.011659939368799329

# %% [markdown]
# ### Time Series Cross Validation on Optimal Model

# %%
# ---------------- config opt model -----------------
opt_model_hor = ml_algorithm(n_neighbors=4, leaf_size=36, p=1)

# %%
opt_model_hor_tscv_scores = cross_validation(data_set, opt_model_hor, 'tau_target_hor')
opt_model_hor_tscv_scores = pd.DataFrame(opt_model_hor_tscv_scores)
display(opt_model_hor_tscv_scores)
display(opt_model_hor_tscv_scores.describe())
# Out:
#    mse_train  mse_valid  mae_train  mae_valid  r2_train  r2_valid
# 0   0.004922   0.012513   0.054278   0.087618  0.810666  0.540220
# 1   0.005081   0.018020   0.055021   0.110933  0.810758  0.459533
# 2   0.005578   0.013248   0.057725   0.093537  0.810732  0.483957
# 3   0.005947   0.011933   0.060597   0.089066  0.797727  0.446017
# 4   0.006180   0.010939   0.062352   0.083845  0.785975  0.426826
# 5   0.005690   0.008144   0.059566   0.070363  0.798016  0.655261
# 6   0.005092   0.007395   0.055588   0.067364  0.819063  0.628407
# 7   0.004828   0.018784   0.053902   0.115875  0.821000 -0.358184
# 8   0.005434   0.008843   0.057660   0.074037  0.794058  0.525316
# 9   0.005280   0.006782   0.056535   0.062162  0.789937  0.671258
#        mse_train  mse_valid  mae_train  mae_valid   r2_train   r2_valid
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.005403   0.011660   0.057322   0.085480   0.803793   0.447861
# std     0.000446   0.004181   0.002813   0.017914   0.012236   0.296581
# min     0.004828   0.006782   0.053902   0.062162   0.785975  -0.358184
# 25%     0.005084   0.008318   0.055163   0.071281   0.794975   0.449396
# 50%     0.005357   0.011436   0.057098   0.085732   0.804341   0.504637
# 75%     0.005662   0.013064   0.059106   0.092419   0.810751   0.606360
# max     0.006180   0.018784   0.062352   0.115875   0.821000   0.671258

# %%
ax = opt_model_hor_tscv_scores[['mse_train', 'mse_valid', 'mae_train', 'mae_valid', 'r2_train', 'r2_valid']].plot(figsize=(8,4))

# %%
ax = opt_model_hor_tscv_scores[['mse_train', 'mse_valid']].plot(figsize=(8,4))

# %%
ax = opt_model_hor_tscv_scores[['mae_train', 'mae_valid']].plot(figsize=(8,4), color=['#2ca02c', '#d62728'])

# %%
ax = opt_model_hor_tscv_scores[['r2_train', 'r2_valid']].plot(figsize=(8,4), color=['#9467bd', '#8c564b'])

# %% [markdown]
# ### Model Performance on Test Set

# %%
opt_model_hor_test_scores = performance_test_shifted(data_set, opt_model_hor, 'tau_target_hor')
opt_model_hor_test_scores = pd.DataFrame(opt_model_hor_test_scores)
display(opt_model_hor_test_scores)
display(opt_model_hor_test_scores.describe())
# Out:
#    mse_train  mse_test  mae_train  mae_test  r2_train   r2_test  ts_mean_true  \
# 0   0.004918  0.018101   0.054168  0.111327  0.815644  0.457093      0.429797
# 1   0.005461  0.013180   0.057084  0.093119  0.813931  0.486602      0.335499
# 2   0.005732  0.011736   0.059319  0.087974  0.801859  0.455164      0.293080
# 3   0.005905  0.010677   0.060558  0.082521  0.793915  0.440561      0.287144
# 4   0.005837  0.007985   0.060269  0.069768  0.791176  0.661990      0.295090
# 5   0.005222  0.007187   0.056486  0.066221  0.812516  0.638851      0.292463
# 6   0.004791  0.019247   0.053695  0.117569  0.824383 -0.391653      0.205042
# 7   0.005439  0.009066   0.057634  0.075016  0.799007  0.513307      0.247086
# 8   0.005167  0.006990   0.056284  0.063087  0.799694  0.661149      0.248710
# 9   0.004922  0.014443   0.054186  0.099949  0.801432  0.225751      0.342639
#
#    ts_mean_estim
# 0       0.341074
# 1       0.374207
# 2       0.362487
# 3       0.347172
# 4       0.328706
# 5       0.319871
# 6       0.315434
# 7       0.279813
# 8       0.269574
# 9       0.259751
#        mse_train   mse_test  mae_train   mae_test   r2_train    r2_test  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.005339   0.011861   0.056968   0.086655   0.805356   0.414882
# std     0.000400   0.004368   0.002511   0.018843   0.010670   0.312167
# min     0.004791   0.006990   0.053695   0.063087   0.791176  -0.391653
# 25%     0.004983   0.008255   0.054711   0.071080   0.799179   0.444212
# 50%     0.005331   0.011206   0.056785   0.085247   0.801645   0.471847
# 75%     0.005664   0.014127   0.058898   0.098241   0.813577   0.607465
# max     0.005905   0.019247   0.060558   0.117569   0.824383   0.661990
#
#        ts_mean_true  ts_mean_estim
# count     10.000000      10.000000
# mean       0.297655       0.319809
# std        0.062015       0.039172
# min        0.205042       0.259751
# 25%        0.258318       0.288718
# 50%        0.292772       0.324288
# 75%        0.325397       0.345648
# max        0.429797       0.374207

# %%
ax = opt_model_hor_test_scores.plot(figsize=(8,4))

# %%
ax = opt_model_hor_test_scores[['mse_train', 'mse_test']].plot(figsize=(8,4))

# %%
ax = opt_model_hor_test_scores[['mae_train', 'mae_test']].plot(figsize=(8,4), color=['#2ca02c', '#d62728'])

# %%
ax = opt_model_hor_test_scores[['r2_train', 'r2_test']].plot(figsize=(8,4), color=['#9467bd', '#8c564b'])

# %%
ax = opt_model_hor_test_scores[['ts_mean_true', 'ts_mean_estim']].plot(figsize=(8,4), color=['#e377c2', '#8c564b'])
plt.ylim([0.2,0.45])
# Out:
# (0.2, 0.45)

# %% [markdown]
# ### Data for Storage

# %%
results_hor = {'Model': [opt_model_ori],
            'fc_horizon': 1,
            'vif': [vif],
            'mse_tscv_t': [opt_model_hor_tscv_scores.mse_train.mean()],
            'mse_tscv_v': [opt_model_hor_tscv_scores.mse_valid.mean()],
            'mse_train': [opt_model_hor_test_scores.mse_train.mean()],
            'mse_test': [opt_model_hor_test_scores.mse_test.mean()],
               
            'mae_tscv_t': [opt_model_hor_tscv_scores.mae_train.mean()],
            'mae_tscv_v': [opt_model_hor_tscv_scores.mae_valid.mean()],
            'mae_train': [opt_model_hor_test_scores.mae_train.mean()],
            'mae_test': [opt_model_hor_test_scores.mae_test.mean()],
               
            'r2_tscv_t': [opt_model_hor_tscv_scores.r2_train.mean()],
            'r2_tscv_v': [opt_model_hor_tscv_scores.r2_valid.mean()],
            'r2_train': [opt_model_hor_test_scores.r2_train.mean()],
            'r2_test': [opt_model_hor_test_scores.r2_test.mean()],
               
            'opt_model': [opt_model_hor.get_params()],
            'ts_mean_true': opt_model_hor_test_scores.ts_mean_true.mean(),
            'ts_mean_estim': opt_model_hor_test_scores.ts_mean_estim.mean(),
              }

# %% [markdown]
# ## Safe to Excel

# %%
results = pd.concat([pd.DataFrame(results_ori), pd.DataFrame(results_hor)])

display(results)

storage_name = filename + '_' + vif + '_' + str(datetime.today().day) + '.xlsx'

pd.DataFrame(results).to_excel(path + 'artifacts' + slash + storage_name, index=None)
# Out:
#                                                   Model  fc_horizon  vif  \
# 0  KNeighborsRegressor(leaf_size=1, n_neighbors=3, p=1)           0  all
# 0  KNeighborsRegressor(leaf_size=1, n_neighbors=3, p=1)           1  all
#
#    mse_tscv_t  mse_tscv_v  mse_train  mse_test  mae_tscv_t  mae_tscv_v  \
# 0    0.004323    0.012161   0.004310  0.010887    0.050799    0.087323
# 0    0.005403    0.011660   0.005339  0.011861    0.057322    0.085480
#
#    mae_train  mae_test  r2_tscv_t  r2_tscv_v  r2_train   r2_test  \
# 0   0.050764  0.082238   0.844857   0.458876  0.846169  0.490718
# 0   0.056968  0.086655   0.803793   0.447861  0.805356  0.414882
#
#                                                                                                                                               opt_model  \
# 0   {'algorithm': 'auto', 'leaf_size': 1, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0  {'algorithm': 'auto', 'leaf_size': 36, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 4, 'p': 1, 'weights': 'uniform'}
#
#    ts_mean_true  ts_mean_estim
# 0      0.296046       0.318064
# 0      0.297655       0.319809
