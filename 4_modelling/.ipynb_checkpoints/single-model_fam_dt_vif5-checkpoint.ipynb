# %% [markdown]
# # Decision Tree (copula family) [vif5]
# This is a simple, yet powerful algorithm that can be used for both regression and classification problems. It works well with categorical data, as well as data with non-linear relationships.
#
# https://scikit-learn.org/stable/modules/tree.html#classification
#
# tree.DecisionTreeClassifier()
#
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}
#
# **_bayesian hyperparameter tuning_**

# %%
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pathlib
import platform
import seaborn as sns
from sklearn import linear_model
from sklearn import tree
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler
from skopt import gp_minimize, space
from skopt.space import Real, Integer
import sys

from validation import cross_validation
from validation import performance_test_shifted

date_format = '%Y-%m-%d'

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.max_colwidth = None

# %%
# config 'all', 'vif_5' or 'vif_10'
vif = 'vif_5'

# config model
ml_algorithm = tree.DecisionTreeClassifier
filename = 'single-model_fam_dt'

# %%
my_os = platform.system()
print('OS in my system: ',my_os)

if my_os == 'Windows':
    path = str(pathlib.Path().absolute()) + '\\'
    slash = '\\'
else:
    path = str(pathlib.Path().absolute()) + '/'
    slash = '/'

path_3 = path.replace('4_modelling', '3_data_pre-processing')
# Out:
# OS in my system:  Linux

# %% [markdown]
# ## Load Data

# %%
data_set = pd.read_csv(path_3 + 'data_artifacts' + slash + 'data_set_e_spx_3-' + vif + '.csv', index_col=0)

# %% [markdown]
# ## Original Target Model (no forecast horizon)
# ### Time Series Cross Validation on Default Model

# %%
default_model = ml_algorithm(random_state=23)
default_model.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 23,
#  'splitter': 'best'}

# %%
default_model_scores_ori = cross_validation (data_set, default_model, 'fam_target_ori')
pd.DataFrame(default_model_scores_ori).describe()
# Out:
#        auc_train  auc_valid  acc_train  acc_valid  prec_train  prec_valid  \
# count       10.0  10.000000       10.0  10.000000        10.0   10.000000
# mean         1.0   0.564402        1.0   0.312409         1.0    0.192490
# std          0.0   0.006424        0.0   0.018232         0.0    0.005158
# min          1.0   0.553758        1.0   0.285343         1.0    0.186254
# 25%          1.0   0.562468        1.0   0.299569         1.0    0.189204
# 50%          1.0   0.564688        1.0   0.310139         1.0    0.190920
# 75%          1.0   0.567082        1.0   0.324930         1.0    0.194712
# max          1.0   0.576291        1.0   0.339713         1.0    0.204230
#
#        rec_train  rec_valid  f1_train   f1_valid
# count       10.0  10.000000      10.0  10.000000
# mean         1.0   0.255170       1.0   0.246904
# std          0.0   0.012286       0.0   0.012289
# min          1.0   0.233542       1.0   0.226667
# 25%          1.0   0.251807       1.0   0.243587
# 50%          1.0   0.257439       1.0   0.247139
# 75%          1.0   0.260900       1.0   0.253711
# max          1.0   0.277047       1.0   0.269564

# %%
ax = pd.DataFrame(default_model_scores_ori).plot(figsize=(8,4))
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %% [markdown]
# ### Hyperparameter Optimization with Time Series Cross Validation
# - Bayesian optimization
# - https://scikit-optimize.github.io/stable/auto_examples/bayesian-optimization.html

# %%
# search space for the hyperparameters
space = [Integer(1, 50, name='max_depth'),
         Integer(2, 200, name='min_samples_split'),
         Integer(1, 200, name='min_samples_leaf')]

# %%
# objective function to minimize
def objective(params):
    max_depth, min_samples_split, min_samples_leaf = params
    model = ml_algorithm(max_depth=int(max_depth), min_samples_split=int(min_samples_split), min_samples_leaf=int(min_samples_leaf), random_state=23)
    scores = cross_validation(data_set, model, 'fam_target_ori')
    return -np.mean(scores['auc_valid'])

# perform the optimization
result = gp_minimize(objective, space, n_calls=100, n_random_starts=20, acq_func='EI', acq_optimizer='lbfgs', random_state=23, n_jobs=-1)

# optimal point and function value
print('Optimal point:', result.x)
print('Function value at optimal point:', result.fun)
ax = pd.DataFrame(result.func_vals).plot(figsize=(12,4))
# Out:
# Optimal point: [23, 11, 3]
# Function value at optimal point: -0.5624346081583323

# %% [markdown]
# ### Time Series Cross Validation on Optimal Model

# %%
# ---------------- config opt model -----------------
opt_model_ori = ml_algorithm(max_depth=23, min_samples_split=11, min_samples_leaf=3, random_state=23)

# %%
opt_model_ori_tscv_scores = cross_validation(data_set, opt_model_ori, 'fam_target_ori')
opt_model_ori_tscv_scores = pd.DataFrame(opt_model_ori_tscv_scores)
display(opt_model_ori_tscv_scores)
display(opt_model_ori_tscv_scores.describe())
# Out:
#    auc_train  auc_valid  acc_train  acc_valid  prec_train  prec_valid  \
# 0   0.772639   0.575399   0.651246   0.305138    0.566533    0.203118
# 1   0.766034   0.569880   0.629654   0.303591    0.551833    0.196670
# 2   0.783733   0.567630   0.663618   0.320574    0.588173    0.192403
# 3   0.773636   0.549035   0.663492   0.240125    0.568167    0.185876
# 4   0.772921   0.559851   0.670558   0.263425    0.566919    0.201966
# 5   0.767721   0.566134   0.660791   0.268505    0.556537    0.196506
# 6   0.773977   0.565089   0.659712   0.260697    0.570757    0.203487
# 7   0.780150   0.563124   0.658938   0.278377    0.580455    0.199455
# 8   0.773858   0.549624   0.652454   0.244803    0.568977    0.190412
# 9   0.766573   0.558581   0.651035   0.268396    0.554374    0.196078
#
#    rec_train  rec_valid  f1_train  f1_valid
# 0   0.566533   0.242023  0.655332  0.246874
# 1   0.551833   0.234614  0.644915  0.251231
# 2   0.588173   0.235582  0.677713  0.249431
# 3   0.568167   0.201582  0.657129  0.202989
# 4   0.566919   0.216676  0.655983  0.230117
# 5   0.556537   0.218119  0.647132  0.234939
# 6   0.570757   0.222651  0.661368  0.246585
# 7   0.580455   0.221891  0.672930  0.242353
# 8   0.568977   0.190217  0.663155  0.207553
# 9   0.554374   0.208896  0.645219  0.215449
#        auc_train  auc_valid  acc_train  acc_valid  prec_train  prec_valid  \
# count  10.000000  10.000000  10.000000  10.000000   10.000000   10.000000
# mean    0.773124   0.562435   0.656150   0.275363    0.567273    0.196597
# std     0.005638   0.008412   0.011181   0.026594    0.011290    0.005755
# min     0.766034   0.549035   0.629654   0.240125    0.551833    0.185876
# 25%     0.768951   0.558899   0.651548   0.261379    0.559036    0.193322
# 50%     0.773279   0.564106   0.659325   0.268451    0.567543    0.196588
# 75%     0.773947   0.567256   0.662817   0.297288    0.570312    0.201338
# max     0.783733   0.575399   0.670558   0.320574    0.588173    0.203487
#
#        rec_train  rec_valid   f1_train   f1_valid
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.567273   0.219225   0.658088   0.232752
# std     0.011290   0.016021   0.011125   0.018057
# min     0.551833   0.190217   0.644915   0.202989
# 25%     0.559036   0.210841   0.649182   0.219116
# 50%     0.567543   0.220005   0.656556   0.238646
# 75%     0.570312   0.231623   0.662708   0.246802
# max     0.588173   0.242023   0.677713   0.251231

# %%
ax = opt_model_ori_tscv_scores.plot(figsize=(8,4))

# %%
ax = opt_model_ori_tscv_scores[['auc_train', 'auc_valid']].plot(figsize=(8,4))

# %%
ax = opt_model_ori_tscv_scores[['acc_train', 'acc_valid']].plot(figsize=(8,4), color=['#2ca02c', '#d62728'])

# %%
ax = opt_model_ori_tscv_scores[['prec_train', 'prec_valid']].plot(figsize=(8,4), color=['#9467bd', '#8c564b'])

# %%
ax = opt_model_ori_tscv_scores[['rec_train', 'rec_valid']].plot(figsize=(8,4), color=['#e377c2', '#8c564b'])

# %%
ax = opt_model_ori_tscv_scores[['f1_train', 'f1_valid']].plot(figsize=(8,4), color=['#bcbd22', '#17becf'])

# %% [markdown]
# ### Model Performance on Test Set

# %%
opt_model_ori_test_scores = performance_test_shifted(data_set, opt_model_ori, 'fam_target_ori')
opt_model_ori_test_scores = pd.DataFrame(opt_model_ori_test_scores)
display(opt_model_ori_test_scores)
display(opt_model_ori_test_scores.describe())
# Out:
#    auc_train  auc_test  acc_train  acc_test  prec_train  prec_test  rec_train  \
# 0   0.776310  0.568343   0.647260  0.305275    0.572970   0.197179   0.572970
# 1   0.768017  0.567343   0.627693  0.303030    0.555546   0.202340   0.555546
# 2   0.778546  0.560476   0.661373  0.237526    0.577076   0.193579   0.577076
# 3   0.776142  0.566924   0.659608  0.262918    0.572927   0.201752   0.572927
# 4   0.774561  0.560405   0.657182  0.265119    0.569829   0.195002   0.569829
# 5   0.766960  0.556028   0.647024  0.244376    0.556498   0.195087   0.556498
# 6   0.769493  0.561555   0.651711  0.272335    0.559049   0.198953   0.559049
# 7   0.773760  0.557385   0.659831  0.232923    0.568737   0.186998   0.568737
# 8   0.775850  0.568287   0.660886  0.281157    0.573192   0.200230   0.573192
# 9   0.758810  0.554434   0.631342  0.273482    0.539229   0.189736   0.539229
#
#    rec_test  f1_train   f1_test  \
# 0  0.229364  0.665584  0.249741
# 1  0.233746  0.652481  0.252871
# 2  0.226504  0.667597  0.238704
# 3  0.230196  0.663972  0.248021
# 4  0.217312  0.661412  0.232250
# 5  0.202347  0.648611  0.231449
# 6  0.220035  0.654323  0.247815
# 7  0.208946  0.660629  0.208467
# 8  0.225029  0.661211  0.236150
# 9  0.200946  0.635727  0.214460
#
#                                                                                                                                                                                                                                                                  ts_mean_true  \
# 0  fam_target_ori_clayton     0.030864
# fam_target_ori_frank       0.045455
# fam_target_ori_gaussian    0.212682
# fam_target_ori_gumbel      0.332772
# fam_target_ori_indep       0.072952
# fam_target_ori_joe         0.017957
# fam_target_ori_student     0.287318
# dtype: float64
# 1  fam_target_ori_clayton     0.015417
# fam_target_ori_frank       0.041999
# fam_target_ori_gaussian    0.143009
# fam_target_ori_gumbel      0.358320
# fam_target_ori_indep       0.050505
# fam_target_ori_joe         0.017544
# fam_target_ori_student     0.373206
# dtype: float64
# 2  fam_target_ori_clayton     0.027027
# fam_target_ori_frank       0.161123
# fam_target_ori_gaussian    0.306133
# fam_target_ori_gumbel      0.240644
# fam_target_ori_indep       0.092516
# fam_target_ori_joe         0.010395
# fam_target_ori_student     0.162162
# dtype: float64
# 3  fam_target_ori_clayton     0.054205
# fam_target_ori_frank       0.111449
# fam_target_ori_gaussian    0.235562
# fam_target_ori_gumbel      0.372847
# fam_target_ori_indep       0.110436
# fam_target_ori_joe         0.035968
# fam_target_ori_student     0.079534
# dtype: float64
# 4  fam_target_ori_clayton     0.061442
# fam_target_ori_frank       0.212869
# fam_target_ori_gaussian    0.164973
# fam_target_ori_gumbel      0.388002
# fam_target_ori_indep       0.096759
# fam_target_ori_joe         0.017417
# fam_target_ori_student     0.058539
# dtype: float64
# 5  fam_target_ori_clayton     0.026908
# fam_target_ori_frank       0.215704
# fam_target_ori_gaussian    0.235112
# fam_target_ori_gumbel      0.280988
# fam_target_ori_indep       0.109396
# fam_target_ori_joe         0.019850
# fam_target_ori_student     0.112042
# dtype: float64
# 6  fam_target_ori_clayton     0.025896
# fam_target_ori_frank       0.132067
# fam_target_ori_gaussian    0.153215
# fam_target_ori_gumbel      0.429003
# fam_target_ori_indep       0.090203
# fam_target_ori_joe         0.021148
# fam_target_ori_student     0.148468
# dtype: float64
# 7  fam_target_ori_clayton     0.045397
# fam_target_ori_frank       0.203224
# fam_target_ori_gaussian    0.302503
# fam_target_ori_gumbel      0.234196
# fam_target_ori_indep       0.170132
# fam_target_ori_joe         0.010607
# fam_target_ori_student     0.033941
# dtype: float64
# 8  fam_target_ori_clayton     0.054870
# fam_target_ori_frank       0.066780
# fam_target_ori_gaussian    0.169715
# fam_target_ori_gumbel      0.437686
# fam_target_ori_indep       0.113994
# fam_target_ori_joe         0.031476
# fam_target_ori_student     0.125479
# dtype: float64
# 9  fam_target_ori_clayton     0.048930
# fam_target_ori_frank       0.104849
# fam_target_ori_gaussian    0.232416
# fam_target_ori_gumbel      0.396680
# fam_target_ori_indep       0.115771
# fam_target_ori_joe         0.027523
# fam_target_ori_student     0.073831
# dtype: float64
#
#                                                                                                       ts_mean_estim
# 0  0    0.009540
# 1    0.077441
# 2    0.091470
# 3    0.219978
# 4    0.051066
# 5    0.006173
# 6    0.335017
# dtype: float64
# 1  0    0.009569
# 1    0.040936
# 2    0.125465
# 3    0.228602
# 4    0.051568
# 5    0.007443
# 6    0.331738
# dtype: float64
# 2  0    0.008316
# 1    0.040021
# 2    0.133576
# 3    0.276507
# 4    0.058732
# 5    0.009356
# 6    0.293139
# dtype: float64
# 3  0    0.008105
# 1    0.072442
# 2    0.176798
# 3    0.253293
# 4    0.073961
# 5    0.011651
# 6    0.190983
# dtype: float64
# 4  0    0.019836
# 1    0.081277
# 2    0.176101
# 3    0.300435
# 4    0.088534
# 5    0.019836
# 6    0.096759
# dtype: float64
# 5  0    0.020291
# 1    0.109396
# 2    0.146449
# 3    0.296868
# 4    0.088663
# 5    0.010587
# 6    0.060432
# dtype: float64
# 6  0    0.012948
# 1    0.104877
# 2    0.145878
# 3    0.323694
# 4    0.078981
# 5    0.010358
# 6    0.091498
# dtype: float64
# 7  0    0.011455
# 1    0.091218
# 2    0.122189
# 3    0.323292
# 4    0.095036
# 5    0.020365
# 6    0.093763
# dtype: float64
# 8  0    0.017439
# 1    0.133560
# 2    0.165887
# 3    0.270098
# 4    0.115270
# 5    0.014037
# 6    0.040408
# dtype: float64
# 9  0    0.028834
# 1    0.083443
# 2    0.147663
# 3    0.304937
# 4    0.128877
# 5    0.010485
# 6    0.052425
# dtype: float64
#        auc_train   auc_test  acc_train   acc_test  prec_train  prec_test  \
# count  10.000000  10.000000  10.000000  10.000000   10.000000  10.000000
# mean    0.771845   0.562118   0.650391   0.267814    0.564505   0.196086
# std     0.006003   0.005288   0.012256   0.024921    0.011716   0.005046
# min     0.758810   0.554434   0.627693   0.232923    0.539229   0.186998
# 25%     0.768386   0.558140   0.647083   0.249011    0.557136   0.193935
# 50%     0.774160   0.561015   0.654447   0.268727    0.569283   0.196133
# 75%     0.776069   0.567239   0.659776   0.279238    0.572959   0.199911
# max     0.778546   0.568343   0.661373   0.305275    0.577076   0.202340
#
#        rec_train   rec_test   f1_train    f1_test
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.564505   0.219443   0.657155   0.235993
# std     0.011716   0.011781   0.009634   0.014988
# min     0.539229   0.200946   0.635727   0.208467
# 25%     0.557136   0.211038   0.652942   0.231649
# 50%     0.569283   0.222532   0.660920   0.237427
# 75%     0.572959   0.228649   0.663332   0.247970
# max     0.577076   0.233746   0.667597   0.252871

# %%
ax = opt_model_ori_test_scores.plot(figsize=(9,4))

# %%
ax = opt_model_ori_test_scores[['auc_train', 'auc_test']].plot(figsize=(8,4))

# %%
ax = opt_model_ori_test_scores[['acc_train', 'acc_test']].plot(figsize=(8,4), color=['#2ca02c', '#d62728'])

# %%
ax = opt_model_ori_test_scores[['prec_train', 'prec_test']].plot(figsize=(8,4), color=['#9467bd', '#8c564b'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_ori_test_scores[['rec_train', 'rec_test']].plot(figsize=(8,4), color=['#e377c2', '#8c564b'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_ori_test_scores[['f1_train', 'f1_test']].plot(figsize=(8,4), color=['#bcbd22', '#17becf'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
opt_model_ori_test_scores[['ts_mean_true', 'ts_mean_estim']]
# Out:
#                                                                                                                                                                                                                                                                  ts_mean_true  \
# 0  fam_target_ori_clayton     0.030864
# fam_target_ori_frank       0.045455
# fam_target_ori_gaussian    0.212682
# fam_target_ori_gumbel      0.332772
# fam_target_ori_indep       0.072952
# fam_target_ori_joe         0.017957
# fam_target_ori_student     0.287318
# dtype: float64
# 1  fam_target_ori_clayton     0.015417
# fam_target_ori_frank       0.041999
# fam_target_ori_gaussian    0.143009
# fam_target_ori_gumbel      0.358320
# fam_target_ori_indep       0.050505
# fam_target_ori_joe         0.017544
# fam_target_ori_student     0.373206
# dtype: float64
# 2  fam_target_ori_clayton     0.027027
# fam_target_ori_frank       0.161123
# fam_target_ori_gaussian    0.306133
# fam_target_ori_gumbel      0.240644
# fam_target_ori_indep       0.092516
# fam_target_ori_joe         0.010395
# fam_target_ori_student     0.162162
# dtype: float64
# 3  fam_target_ori_clayton     0.054205
# fam_target_ori_frank       0.111449
# fam_target_ori_gaussian    0.235562
# fam_target_ori_gumbel      0.372847
# fam_target_ori_indep       0.110436
# fam_target_ori_joe         0.035968
# fam_target_ori_student     0.079534
# dtype: float64
# 4  fam_target_ori_clayton     0.061442
# fam_target_ori_frank       0.212869
# fam_target_ori_gaussian    0.164973
# fam_target_ori_gumbel      0.388002
# fam_target_ori_indep       0.096759
# fam_target_ori_joe         0.017417
# fam_target_ori_student     0.058539
# dtype: float64
# 5  fam_target_ori_clayton     0.026908
# fam_target_ori_frank       0.215704
# fam_target_ori_gaussian    0.235112
# fam_target_ori_gumbel      0.280988
# fam_target_ori_indep       0.109396
# fam_target_ori_joe         0.019850
# fam_target_ori_student     0.112042
# dtype: float64
# 6  fam_target_ori_clayton     0.025896
# fam_target_ori_frank       0.132067
# fam_target_ori_gaussian    0.153215
# fam_target_ori_gumbel      0.429003
# fam_target_ori_indep       0.090203
# fam_target_ori_joe         0.021148
# fam_target_ori_student     0.148468
# dtype: float64
# 7  fam_target_ori_clayton     0.045397
# fam_target_ori_frank       0.203224
# fam_target_ori_gaussian    0.302503
# fam_target_ori_gumbel      0.234196
# fam_target_ori_indep       0.170132
# fam_target_ori_joe         0.010607
# fam_target_ori_student     0.033941
# dtype: float64
# 8  fam_target_ori_clayton     0.054870
# fam_target_ori_frank       0.066780
# fam_target_ori_gaussian    0.169715
# fam_target_ori_gumbel      0.437686
# fam_target_ori_indep       0.113994
# fam_target_ori_joe         0.031476
# fam_target_ori_student     0.125479
# dtype: float64
# 9  fam_target_ori_clayton     0.048930
# fam_target_ori_frank       0.104849
# fam_target_ori_gaussian    0.232416
# fam_target_ori_gumbel      0.396680
# fam_target_ori_indep       0.115771
# fam_target_ori_joe         0.027523
# fam_target_ori_student     0.073831
# dtype: float64
#
#                                                                                                       ts_mean_estim
# 0  0    0.009540
# 1    0.077441
# 2    0.091470
# 3    0.219978
# 4    0.051066
# 5    0.006173
# 6    0.335017
# dtype: float64
# 1  0    0.009569
# 1    0.040936
# 2    0.125465
# 3    0.228602
# 4    0.051568
# 5    0.007443
# 6    0.331738
# dtype: float64
# 2  0    0.008316
# 1    0.040021
# 2    0.133576
# 3    0.276507
# 4    0.058732
# 5    0.009356
# 6    0.293139
# dtype: float64
# 3  0    0.008105
# 1    0.072442
# 2    0.176798
# 3    0.253293
# 4    0.073961
# 5    0.011651
# 6    0.190983
# dtype: float64
# 4  0    0.019836
# 1    0.081277
# 2    0.176101
# 3    0.300435
# 4    0.088534
# 5    0.019836
# 6    0.096759
# dtype: float64
# 5  0    0.020291
# 1    0.109396
# 2    0.146449
# 3    0.296868
# 4    0.088663
# 5    0.010587
# 6    0.060432
# dtype: float64
# 6  0    0.012948
# 1    0.104877
# 2    0.145878
# 3    0.323694
# 4    0.078981
# 5    0.010358
# 6    0.091498
# dtype: float64
# 7  0    0.011455
# 1    0.091218
# 2    0.122189
# 3    0.323292
# 4    0.095036
# 5    0.020365
# 6    0.093763
# dtype: float64
# 8  0    0.017439
# 1    0.133560
# 2    0.165887
# 3    0.270098
# 4    0.115270
# 5    0.014037
# 6    0.040408
# dtype: float64
# 9  0    0.028834
# 1    0.083443
# 2    0.147663
# 3    0.304937
# 4    0.128877
# 5    0.010485
# 6    0.052425
# dtype: float64

# %% [markdown]
# ### Data for Storage

# %%
results_ori = {'Model': [opt_model_ori],
            'fc_horizon': 0,
            'vif': [vif],
            'auc_tscv_t': [opt_model_ori_tscv_scores.auc_train.mean()],
            'auc_tscv_v': [opt_model_ori_tscv_scores.auc_valid.mean()],
            'auc_train': [opt_model_ori_test_scores.auc_train.mean()],
            'auc_test': [opt_model_ori_test_scores.auc_test.mean()],
               
            'acc_tscv_t': [opt_model_ori_tscv_scores.acc_train.mean()],
            'acc_tscv_v': [opt_model_ori_tscv_scores.acc_valid.mean()],
            'acc_train': [opt_model_ori_test_scores.acc_train.mean()],
            'acc_test': [opt_model_ori_test_scores.acc_test.mean()],
               
            'prec_tscv_t': [opt_model_ori_tscv_scores.prec_train.mean()],
            'prec_tscv_v': [opt_model_ori_tscv_scores.prec_valid.mean()],
            'prec_train': [opt_model_ori_test_scores.prec_train.mean()],
            'prec_test': [opt_model_ori_test_scores.prec_test.mean()],
               
            'rec_tscv_t': [opt_model_ori_tscv_scores.rec_train.mean()],
            'rec_tscv_v': [opt_model_ori_tscv_scores.rec_valid.mean()],
            'rec_train': [opt_model_ori_test_scores.rec_train.mean()],
            'rec_test': [opt_model_ori_test_scores.rec_test.mean()],
               
            'f1_tscv_t': [opt_model_ori_tscv_scores.f1_train.mean()],
            'f1_tscv_v': [opt_model_ori_tscv_scores.f1_valid.mean()],
            'f1_train': [opt_model_ori_test_scores.f1_train.mean()],
            'f1_test': [opt_model_ori_test_scores.f1_test.mean()],
               
            'opt_model': [opt_model_ori.get_params()],
#             'ts_mean_true': opt_model_ori_test_scores.ts_mean_true,
#             'ts_mean_estim': opt_model_ori_test_scores.ts_mean_estim
              }

# %% [markdown]
# ## ----------------------------------------------------------
# ## Predicted Target Model (one year forecast horizon)
# ### Time Series Cross Validation on Default Model

# %%
default_model_scores_hor = cross_validation (data_set, default_model, 'fam_target_hor')
pd.DataFrame(default_model_scores_hor).describe()
# Out:
#        auc_train  auc_valid  acc_train  acc_valid  prec_train  prec_valid  \
# count       10.0  10.000000       10.0  10.000000        10.0   10.000000
# mean         1.0   0.554273        1.0   0.294989         1.0    0.178666
# std          0.0   0.006514        0.0   0.026258         0.0    0.007088
# min          1.0   0.543065        1.0   0.264753         1.0    0.171058
# 25%          1.0   0.550341        1.0   0.276092         1.0    0.173541
# 50%          1.0   0.554649        1.0   0.289239         1.0    0.177496
# 75%          1.0   0.557979        1.0   0.313712         1.0    0.181852
# max          1.0   0.562914        1.0   0.346801         1.0    0.194299
#
#        rec_train  rec_valid  f1_train   f1_valid
# count       10.0  10.000000      10.0  10.000000
# mean         1.0   0.237413       1.0   0.227605
# std          0.0   0.011140       0.0   0.012528
# min          1.0   0.218889       1.0   0.205084
# 25%          1.0   0.230003       1.0   0.218686
# 50%          1.0   0.237115       1.0   0.229784
# 75%          1.0   0.245330       1.0   0.234264
# max          1.0   0.253163       1.0   0.248950

# %%
ax = pd.DataFrame(default_model_scores_hor).plot(figsize=(8,4))

# %% [markdown]
# ### Hyperparameter Optimization with Time Series Cross Validation
# - Bayesian optimization
# - https://scikit-optimize.github.io/stable/auto_examples/bayesian-optimization.html

# %%
# objective function to minimize
def objective(params):
    max_depth, min_samples_split, min_samples_leaf = params
    model = ml_algorithm(max_depth=int(max_depth), min_samples_split=int(min_samples_split), min_samples_leaf=int(min_samples_leaf), random_state=23)
    scores = cross_validation(data_set, model, 'fam_target_hor')
    return -np.mean(scores['auc_valid'])

# perform the optimization
result = gp_minimize(objective, space, n_calls=100, n_random_starts=20, acq_func='EI', acq_optimizer='lbfgs', random_state=23, n_jobs=-1)

# optimal point and function value
print('Optimal point:', result.x)
print('Function value at optimal point:', result.fun)
ax = pd.DataFrame(result.func_vals).plot(figsize=(12,4))
# Out:
# /home/sc.uni-leipzig.de/ae085wyju/.local/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Optimal point: [39, 4, 1]
# Function value at optimal point: -0.5516125895089978

# %% [markdown]
# ### Time Series Cross Validation on Optimal Model

# %%
# ---------------- config opt model -----------------
opt_model_hor = ml_algorithm(max_depth=39, min_samples_split=4, min_samples_leaf=1, random_state=23)

# %%
opt_model_hor_tscv_scores = cross_validation(data_set, opt_model_hor, 'fam_target_hor')
opt_model_hor_tscv_scores = pd.DataFrame(opt_model_hor_tscv_scores)
display(opt_model_hor_tscv_scores)
display(opt_model_hor_tscv_scores.describe())
# Out:
#    auc_train  auc_valid  acc_train  acc_valid  prec_train  prec_valid  \
# 0   0.923956   0.556113   0.896957   0.291980    0.851034    0.180996
# 1   0.925302   0.551615   0.897556   0.322671    0.854096    0.171572
# 2   0.923298   0.541985   0.902815   0.241893    0.850259    0.168066
# 3   0.921378   0.557185   0.901820   0.271830    0.845916    0.190857
# 4   0.915617   0.544171   0.892052   0.252786    0.834677    0.169692
# 5   0.921986   0.549404   0.896825   0.256894    0.847709    0.178393
# 6   0.916298   0.564256   0.894443   0.285840    0.836261    0.183473
# 7   0.917476   0.547546   0.896278   0.252913    0.838745    0.176804
# 8   0.919298   0.552565   0.895306   0.292321    0.842105    0.178467
# 9   0.920614   0.551286   0.895105   0.294768    0.844673    0.177943
#
#    rec_train  rec_valid  f1_train  f1_valid
# 0   0.851034   0.230697  0.906842  0.237516
# 1   0.854096   0.220140  0.909016  0.215496
# 2   0.850259   0.207197  0.905046  0.206233
# 3   0.845916   0.232408  0.904865  0.230601
# 4   0.834677   0.208718  0.894084  0.199211
# 5   0.847709   0.215431  0.903685  0.223150
# 6   0.836261   0.244743  0.895043  0.244436
# 7   0.838745   0.214214  0.897381  0.199730
# 8   0.842105   0.221183  0.900855  0.220790
# 9   0.844673   0.215512  0.902737  0.223501
#        auc_train  auc_valid  acc_train  acc_valid  prec_train  prec_valid  \
# count  10.000000  10.000000  10.000000  10.000000   10.000000   10.000000
# mean    0.920522   0.551613   0.896916   0.276390    0.844547    0.177626
# std     0.003298   0.006512   0.003254   0.025309    0.006528    0.006780
# min     0.915617   0.541985   0.892052   0.241893    0.834677    0.168066
# 25%     0.917931   0.548010   0.895156   0.253908    0.839585    0.172880
# 50%     0.920996   0.551450   0.896552   0.278835    0.845294    0.178168
# 75%     0.922970   0.555226   0.897406   0.292236    0.849622    0.180364
# max     0.925302   0.564256   0.902815   0.322671    0.854096    0.190857
#
#        rec_train  rec_valid   f1_train   f1_valid
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.844547   0.221024   0.901955   0.220066
# std     0.006528   0.011725   0.005025   0.015246
# min     0.834677   0.207197   0.894084   0.199211
# 25%     0.839585   0.214518   0.898249   0.208549
# 50%     0.845294   0.217826   0.903211   0.221970
# 75%     0.849622   0.228319   0.905001   0.228826
# max     0.854096   0.244743   0.909016   0.244436

# %%
ax = opt_model_hor_tscv_scores.plot(figsize=(9,5))

# %%
ax = opt_model_hor_tscv_scores[['auc_train', 'auc_valid']].plot(figsize=(8,4))
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_hor_tscv_scores[['acc_train', 'acc_valid']].plot(figsize=(8,4), color=['#2ca02c', '#d62728'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_hor_tscv_scores[['prec_train', 'prec_valid']].plot(figsize=(8,4), color=['#9467bd', '#8c564b'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_hor_tscv_scores[['rec_train', 'rec_valid']].plot(figsize=(8,4), color=['#e377c2', '#8c564b'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_hor_tscv_scores[['f1_train', 'f1_valid']].plot(figsize=(8,4), color=['#bcbd22', '#17becf'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %% [markdown]
# ### Model Performance on Test Set

# %%
opt_model_hor_test_scores = performance_test_shifted(data_set, opt_model_hor, 'fam_target_hor')
opt_model_hor_test_scores = pd.DataFrame(opt_model_hor_test_scores)
display(opt_model_hor_test_scores)
display(opt_model_hor_test_scores.describe())
# Out:
#    auc_train  auc_test  acc_train  acc_test  prec_train  prec_test  rec_train  \
# 0   0.920439  0.551022   0.898314  0.309203    0.844278   0.174153   0.844278
# 1   0.917099  0.540353   0.896704  0.241361    0.837672   0.168136   0.837672
# 2   0.916914  0.550481   0.897430  0.256237    0.837262   0.188276   0.837262
# 3   0.920533  0.542540   0.899420  0.250760    0.844391   0.173655   0.844391
# 4   0.914678  0.558870   0.891298  0.265119    0.832791   0.179700   0.832791
# 5   0.920728  0.544623   0.895722  0.268637    0.845017   0.168490   0.845017
# 6   0.921075  0.554688   0.897262  0.259387    0.845680   0.178969   0.845680
# 7   0.918410  0.549299   0.895184  0.272804    0.840166   0.179369   0.840166
# 8   0.919140  0.545868   0.897165  0.288813    0.842162   0.174091   0.842162
# 9   0.917076  0.535340   0.891966  0.202272    0.837824   0.152566   0.837824
#
#    rec_test  f1_train   f1_test  \
# 0  0.219927  0.900570  0.218114
# 1  0.205486  0.895718  0.207184
# 2  0.219202  0.897463  0.222046
# 3  0.206909  0.902744  0.205731
# 4  0.235128  0.893212  0.242464
# 5  0.210089  0.902851  0.214122
# 6  0.227729  0.902935  0.212216
# 7  0.214154  0.899527  0.219797
# 8  0.209965  0.898554  0.216805
# 9  0.194089  0.897237  0.120778
#
#                                                                                                                                                                                                                                                                  ts_mean_true  \
# 0  fam_target_hor_clayton     0.015152
# fam_target_hor_frank       0.042088
# fam_target_hor_gaussian    0.143098
# fam_target_hor_gumbel      0.356341
# fam_target_hor_indep       0.049944
# fam_target_hor_joe         0.016274
# fam_target_hor_student     0.377104
# dtype: float64
# 1  fam_target_hor_clayton     0.022860
# fam_target_hor_frank       0.162148
# fam_target_hor_gaussian    0.307283
# fam_target_hor_gumbel      0.243488
# fam_target_hor_indep       0.086656
# fam_target_hor_joe         0.010633
# fam_target_hor_student     0.166932
# dtype: float64
# 2  fam_target_hor_clayton     0.051455
# fam_target_hor_frank       0.111746
# fam_target_hor_gaussian    0.235447
# fam_target_hor_gumbel      0.373181
# fam_target_hor_indep       0.102911
# fam_target_hor_joe         0.040021
# fam_target_hor_student     0.085239
# dtype: float64
# 3  fam_target_hor_clayton     0.057244
# fam_target_hor_frank       0.211246
# fam_target_hor_gaussian    0.165147
# fam_target_hor_gumbel      0.397670
# fam_target_hor_indep       0.093212
# fam_target_hor_joe         0.017224
# fam_target_hor_student     0.058257
# dtype: float64
# 4  fam_target_hor_clayton     0.025157
# fam_target_hor_frank       0.210450
# fam_target_hor_gaussian    0.241413
# fam_target_hor_gumbel      0.283986
# fam_target_hor_indep       0.100629
# fam_target_hor_joe         0.021771
# fam_target_hor_student     0.116594
# dtype: float64
# 5  fam_target_hor_clayton     0.027790
# fam_target_hor_frank       0.132333
# fam_target_hor_gaussian    0.154830
# fam_target_hor_gumbel      0.432289
# fam_target_hor_indep       0.084693
# fam_target_hor_joe         0.020732
# fam_target_hor_student     0.147331
# dtype: float64
# 6  fam_target_hor_clayton     0.047044
# fam_target_hor_frank       0.205006
# fam_target_hor_gaussian    0.300388
# fam_target_hor_gumbel      0.247734
# fam_target_hor_indep       0.156237
# fam_target_hor_joe         0.008632
# fam_target_hor_student     0.034959
# dtype: float64
# 7  fam_target_hor_clayton     0.052185
# fam_target_hor_frank       0.069156
# fam_target_hor_gaussian    0.165040
# fam_target_hor_gumbel      0.440815
# fam_target_hor_indep       0.108613
# fam_target_hor_joe         0.033941
# fam_target_hor_student     0.130250
# dtype: float64
# 8  fam_target_hor_clayton     0.051042
# fam_target_hor_frank       0.107188
# fam_target_hor_gaussian    0.227988
# fam_target_hor_gumbel      0.399830
# fam_target_hor_indep       0.113569
# fam_target_hor_joe         0.027222
# fam_target_hor_student     0.073160
# dtype: float64
# 9  fam_target_hor_clayton     0.013106
# fam_target_hor_frank       0.007864
# fam_target_hor_gaussian    0.029270
# fam_target_hor_gumbel      0.363478
# fam_target_hor_indep       0.015291
# fam_target_hor_joe         0.083006
# fam_target_hor_student     0.487986
# dtype: float64
#
#                                                                                                       ts_mean_estim
# 0  0    0.012907
# 1    0.081369
# 2    0.169473
# 3    0.254209
# 4    0.056678
# 5    0.015152
# 6    0.324916
# dtype: float64
# 1  0    0.012759
# 1    0.060074
# 2    0.130250
# 3    0.325359
# 4    0.043594
# 5    0.011696
# 6    0.348219
# dtype: float64
# 2  0    0.018711
# 1    0.095634
# 2    0.220374
# 3    0.240644
# 4    0.066528
# 5    0.005717
# 6    0.267152
# dtype: float64
# 3  0    0.018237
# 1    0.091185
# 2    0.197568
# 3    0.326241
# 4    0.073961
# 5    0.021783
# 6    0.181358
# dtype: float64
# 4  0    0.022738
# 1    0.114175
# 2    0.152879
# 3    0.350266
# 4    0.089018
# 5    0.018384
# 6    0.163038
# dtype: float64
# 5  0    0.026026
# 1    0.143361
# 2    0.197177
# 3    0.306573
# 4    0.086017
# 5    0.019850
# 6    0.135421
# dtype: float64
# 6  0    0.025464
# 1    0.140699
# 2    0.164868
# 3    0.328874
# 4    0.078981
# 5    0.022443
# 6    0.164868
# dtype: float64
# 7  0    0.032669
# 1    0.152312
# 2    0.212558
# 3    0.286381
# 4    0.116249
# 5    0.012728
# 6    0.090793
# dtype: float64
# 8  0    0.036580
# 1    0.122076
# 2    0.185028
# 3    0.353041
# 4    0.109741
# 5    0.024670
# 6    0.086772
# dtype: float64
# 9  0    0.041066
# 1    0.119266
# 2    0.206640
# 3    0.334644
# 4    0.109218
# 5    0.022717
# 6    0.079074
# dtype: float64
#        auc_train   auc_test  acc_train   acc_test  prec_train  prec_test  \
# count  10.000000  10.000000  10.000000  10.000000   10.000000  10.000000
# mean    0.918609   0.547308   0.896046   0.261459    0.840724   0.173741
# std     0.002132   0.006989   0.002617   0.028430    0.004270   0.009507
# min     0.914678   0.535340   0.891298   0.202272    0.832791   0.152566
# 25%     0.917082   0.543061   0.895319   0.252129    0.837710   0.169782
# 50%     0.918775   0.547583   0.896934   0.262253    0.841164   0.174122
# 75%     0.920509   0.550887   0.897388   0.271763    0.844363   0.179269
# max     0.921075   0.558870   0.899420   0.309203    0.845680   0.188276
#
#        rec_train   rec_test   f1_train    f1_test
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.840724   0.214268   0.899081   0.207926
# std     0.004270   0.011772   0.003282   0.032271
# min     0.832791   0.194089   0.893212   0.120778
# 25%     0.837710   0.207673   0.897293   0.208442
# 50%     0.841164   0.212121   0.899041   0.215464
# 75%     0.844363   0.219746   0.902201   0.219376
# max     0.845680   0.235128   0.902935   0.242464

# %%
ax = opt_model_hor_test_scores[['auc_train', 'auc_test']].plot(figsize=(8,4))
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_hor_test_scores[['acc_train', 'acc_test']].plot(figsize=(8,4), color=['#2ca02c', '#d62728'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_hor_test_scores[['prec_train', 'prec_test']].plot(figsize=(8,4), color=['#9467bd', '#8c564b'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_hor_test_scores[['rec_train', 'rec_test']].plot(figsize=(8,4), color=['#e377c2', '#8c564b'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_hor_test_scores[['f1_train', 'f1_test']].plot(figsize=(8,4), color=['#bcbd22', '#17becf'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
opt_model_hor_test_scores[['ts_mean_true', 'ts_mean_estim']]

# %% [markdown]
# ### Data for Storage

# %%
results_hor = {'Model': [opt_model_ori],
            'fc_horizon': 1,
            'vif': [vif],
            'auc_tscv_t': [opt_model_hor_tscv_scores.auc_train.mean()],
            'auc_tscv_v': [opt_model_hor_tscv_scores.auc_valid.mean()],
            'auc_train': [opt_model_hor_test_scores.auc_train.mean()],
            'auc_test': [opt_model_hor_test_scores.auc_test.mean()],
               
            'acc_tscv_t': [opt_model_hor_tscv_scores.acc_train.mean()],
            'acc_tscv_v': [opt_model_hor_tscv_scores.acc_valid.mean()],
            'acc_train': [opt_model_hor_test_scores.acc_train.mean()],
            'acc_test': [opt_model_hor_test_scores.acc_test.mean()],
               
            'prec_tscv_t': [opt_model_hor_tscv_scores.prec_train.mean()],
            'prec_tscv_v': [opt_model_hor_tscv_scores.prec_valid.mean()],
            'prec_train': [opt_model_hor_test_scores.prec_train.mean()],
            'prec_test': [opt_model_hor_test_scores.prec_test.mean()],
               
            'rec_tscv_t': [opt_model_hor_tscv_scores.rec_train.mean()],
            'rec_tscv_v': [opt_model_hor_tscv_scores.rec_valid.mean()],
            'rec_train': [opt_model_hor_test_scores.rec_train.mean()],
            'rec_test': [opt_model_hor_test_scores.rec_test.mean()],
               
            'f1_tscv_t': [opt_model_hor_tscv_scores.f1_train.mean()],
            'f1_tscv_v': [opt_model_hor_tscv_scores.f1_valid.mean()],
            'f1_train': [opt_model_hor_test_scores.f1_train.mean()],
            'f1_test': [opt_model_hor_test_scores.f1_test.mean()],
               
            'opt_model': [opt_model_ori.get_params()],
#             'ts_mean_true': opt_model_ori_test_scores.ts_mean_true,
#             'ts_mean_estim': opt_model_ori_test_scores.ts_mean_estim
              }

# %% [markdown]
# ## Safe to Excel

# %%
results = pd.concat([pd.DataFrame(results_ori), pd.DataFrame(results_hor)])

display(results)

storage_name = filename + '_' + vif + '_' + str(datetime.today().day) + '.xlsx'

pd.DataFrame(results).to_excel(path + 'artifacts' + slash + storage_name, index=None)
# Out:
#                                                                                                                      Model  \
# 0  DecisionTreeClassifier(max_depth=23, min_samples_leaf=3, min_samples_split=11,\n                       random_state=23)
# 0  DecisionTreeClassifier(max_depth=23, min_samples_leaf=3, min_samples_split=11,\n                       random_state=23)
#
#    fc_horizon    vif  auc_tscv_t  auc_tscv_v  auc_train  auc_test  acc_tscv_t  \
# 0           0  vif_5    0.773124    0.562435   0.771845  0.562118    0.656150
# 0           1  vif_5    0.920522    0.551613   0.918609  0.547308    0.896916
#
#    acc_tscv_v  acc_train  acc_test  prec_tscv_t  prec_tscv_v  prec_train  \
# 0    0.275363   0.650391  0.267814     0.567273     0.196597    0.564505
# 0    0.276390   0.896046  0.261459     0.844547     0.177626    0.840724
#
#    prec_test  rec_tscv_t  rec_tscv_v  rec_train  rec_test  f1_tscv_t  \
# 0   0.196086    0.567273    0.219225   0.564505  0.219443   0.658088
# 0   0.173741    0.844547    0.221024   0.840724  0.214268   0.901955
#
#    f1_tscv_v  f1_train   f1_test  \
# 0   0.232752  0.657155  0.235993
# 0   0.220066  0.899081  0.207926
#
#                                                                                                                                                                                                                                                                              opt_model
# 0  {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 23, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 3, 'min_samples_split': 11, 'min_weight_fraction_leaf': 0.0, 'random_state': 23, 'splitter': 'best'}
# 0  {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 23, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 3, 'min_samples_split': 11, 'min_weight_fraction_leaf': 0.0, 'random_state': 23, 'splitter': 'best'}
