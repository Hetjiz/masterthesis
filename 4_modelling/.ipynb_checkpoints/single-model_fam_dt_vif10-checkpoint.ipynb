# %% [markdown]
# # Decision Tree (copula family) [vif10]
# This is a simple, yet powerful algorithm that can be used for both regression and classification problems. It works well with categorical data, as well as data with non-linear relationships.
#
# https://scikit-learn.org/stable/modules/tree.html#classification
#
# tree.DecisionTreeClassifier()
#
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}
#
# **_bayesian hyperparameter tuning_**

# %%
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pathlib
import platform
import seaborn as sns
from sklearn import linear_model
from sklearn import tree
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler
from skopt import gp_minimize, space
from skopt.space import Real, Integer
import sys

from validation import cross_validation
from validation import performance_test_shifted

date_format = '%Y-%m-%d'

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.max_colwidth = None

# %%
# config 'all', 'vif_5' or 'vif_10'
vif = 'vif_10'

# config model
ml_algorithm = tree.DecisionTreeClassifier
filename = 'single-model_fam_dt'

# %%
my_os = platform.system()
print('OS in my system: ',my_os)

if my_os == 'Windows':
    path = str(pathlib.Path().absolute()) + '\\'
    slash = '\\'
else:
    path = str(pathlib.Path().absolute()) + '/'
    slash = '/'

path_3 = path.replace('4_modelling', '3_data_pre-processing')
# Out:
# OS in my system:  Linux

# %% [markdown]
# ## Load Data

# %%
data_set = pd.read_csv(path_3 + 'data_artifacts' + slash + 'data_set_e_spx_3-' + vif + '.csv', index_col=0)

# %% [markdown]
# ## Original Target Model (no forecast horizon)
# ### Time Series Cross Validation on Default Model

# %%
default_model = ml_algorithm(random_state=23)
default_model.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 23,
#  'splitter': 'best'}

# %%
default_model_scores_ori = cross_validation (data_set, default_model, 'fam_target_ori')
pd.DataFrame(default_model_scores_ori).describe()
# Out:
#        auc_train  auc_valid  acc_train  acc_valid  prec_train  prec_valid  \
# count       10.0  10.000000       10.0  10.000000        10.0   10.000000
# mean         1.0   0.564480        1.0   0.311133         1.0    0.191262
# std          0.0   0.009187        0.0   0.024354         0.0    0.006661
# min          1.0   0.549925        1.0   0.278586         1.0    0.179471
# 25%          1.0   0.559250        1.0   0.292383         1.0    0.187424
# 50%          1.0   0.563172        1.0   0.307917         1.0    0.191809
# 75%          1.0   0.571298        1.0   0.330557         1.0    0.196336
# max          1.0   0.579039        1.0   0.354599         1.0    0.200362
#
#        rec_train  rec_valid  f1_train   f1_valid
# count       10.0  10.000000      10.0  10.000000
# mean         1.0   0.255602       1.0   0.248037
# std          0.0   0.017004       0.0   0.016841
# min          1.0   0.228221       1.0   0.219013
# 25%          1.0   0.245279       1.0   0.233610
# 50%          1.0   0.253544       1.0   0.253014
# 75%          1.0   0.266947       1.0   0.261017
# max          1.0   0.283360       1.0   0.266589

# %%
ax = pd.DataFrame(default_model_scores_ori).plot(figsize=(8,4))
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %% [markdown]
# ### Hyperparameter Optimization with Time Series Cross Validation
# - Bayesian optimization
# - https://scikit-optimize.github.io/stable/auto_examples/bayesian-optimization.html

# %%
# search space for the hyperparameters
space = [Integer(1, 50, name='max_depth'),
         Integer(2, 200, name='min_samples_split'),
         Integer(1, 200, name='min_samples_leaf')]

# %%
# objective function to minimize
def objective(params):
    max_depth, min_samples_split, min_samples_leaf = params
    model = ml_algorithm(max_depth=int(max_depth), min_samples_split=int(min_samples_split), min_samples_leaf=int(min_samples_leaf), random_state=23)
    scores = cross_validation(data_set, model, 'fam_target_ori')
    return -np.mean(scores['auc_valid'])

# perform the optimization
result = gp_minimize(objective, space, n_calls=100, n_random_starts=20, acq_func='EI', acq_optimizer='lbfgs', random_state=23, n_jobs=-1)

# optimal point and function value
print('Optimal point:', result.x)
print('Function value at optimal point:', result.fun)
ax = pd.DataFrame(result.func_vals).plot(figsize=(12,4))
# Out:
# Optimal point: [35, 12, 17]
# Function value at optimal point: -0.5629023093708663

# %% [markdown]
# ### Time Series Cross Validation on Optimal Model

# %%
# ---------------- config opt model -----------------
opt_model_ori = ml_algorithm(max_depth=35, min_samples_split=12, min_samples_leaf=17, random_state=23)

# %%
opt_model_ori_tscv_scores = cross_validation(data_set, opt_model_ori, 'fam_target_ori')
opt_model_ori_tscv_scores = pd.DataFrame(opt_model_ori_tscv_scores)
display(opt_model_ori_tscv_scores)
display(opt_model_ori_tscv_scores.describe())
# Out:
#    auc_train  auc_valid  acc_train  acc_valid  prec_train  prec_valid  \
# 0   0.641513   0.573869   0.383272   0.305764    0.315332    0.211840
# 1   0.638495   0.568540   0.381230   0.273850    0.306955    0.207682
# 2   0.646192   0.571201   0.404250   0.292929    0.323686    0.212796
# 3   0.639765   0.553573   0.402747   0.204262    0.311046    0.196098
# 4   0.639969   0.559812   0.404286   0.222898    0.312879    0.199182
# 5   0.634934   0.561987   0.392247   0.204644    0.301240    0.202777
# 6   0.639742   0.563285   0.407737   0.224967    0.313465    0.210104
# 7   0.643858   0.561630   0.401803   0.231334    0.320110    0.210314
# 8   0.642458   0.554051   0.414537   0.228681    0.319935    0.197561
# 9   0.641737   0.561075   0.409198   0.247554    0.316488    0.201848
#
#    rec_train  rec_valid  f1_train  f1_valid
# 0   0.315332   0.216498  0.381274  0.227601
# 1   0.306955   0.201600  0.371400  0.221463
# 2   0.323686   0.219801  0.389962  0.241063
# 3   0.311046   0.179826  0.372178  0.195531
# 4   0.312879   0.186457  0.382607  0.208670
# 5   0.301240   0.182689  0.362592  0.203944
# 6   0.313465   0.190036  0.378363  0.220112
# 7   0.320110   0.185915  0.391506  0.214925
# 8   0.319935   0.177600  0.380352  0.195483
# 9   0.316488   0.184922  0.378699  0.198606
#        auc_train  auc_valid  acc_train  acc_valid  prec_train  prec_valid  \
# count  10.000000  10.000000  10.000000  10.000000   10.000000   10.000000
# mean    0.640866   0.562902   0.400131   0.243688    0.314113    0.205020
# std     0.003076   0.006682   0.011031   0.035656    0.006641    0.006257
# min     0.634934   0.553573   0.381230   0.204262    0.301240    0.196098
# 25%     0.639748   0.560128   0.394636   0.223415    0.311505    0.199848
# 50%     0.640741   0.561808   0.403498   0.230007    0.314398    0.205230
# 75%     0.642278   0.567226   0.406875   0.267276    0.319073    0.210262
# max     0.646192   0.573869   0.414537   0.305764    0.323686    0.212796
#
#        rec_train  rec_valid   f1_train   f1_valid
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.314113   0.192535   0.378893   0.212740
# std     0.006641   0.015005   0.008631   0.015077
# min     0.301240   0.177600   0.362592   0.195483
# 25%     0.311505   0.183247   0.373724   0.199941
# 50%     0.314398   0.186186   0.379525   0.211798
# 75%     0.319073   0.198709   0.382273   0.221125
# max     0.323686   0.219801   0.391506   0.241063

# %%
ax = opt_model_ori_tscv_scores.plot(figsize=(8,4))

# %%
ax = opt_model_ori_tscv_scores[['auc_train', 'auc_valid']].plot(figsize=(8,4))

# %%
ax = opt_model_ori_tscv_scores[['acc_train', 'acc_valid']].plot(figsize=(8,4), color=['#2ca02c', '#d62728'])

# %%
ax = opt_model_ori_tscv_scores[['prec_train', 'prec_valid']].plot(figsize=(8,4), color=['#9467bd', '#8c564b'])

# %%
ax = opt_model_ori_tscv_scores[['rec_train', 'rec_valid']].plot(figsize=(8,4), color=['#e377c2', '#8c564b'])

# %%
ax = opt_model_ori_tscv_scores[['f1_train', 'f1_valid']].plot(figsize=(8,4), color=['#bcbd22', '#17becf'])

# %% [markdown]
# ### Model Performance on Test Set

# %%
opt_model_ori_test_scores = performance_test_shifted(data_set, opt_model_ori, 'fam_target_ori')
opt_model_ori_test_scores = pd.DataFrame(opt_model_ori_test_scores)
display(opt_model_ori_test_scores)
display(opt_model_ori_test_scores.describe())
# Out:
#    auc_train  auc_test  acc_train  acc_test  prec_train  prec_test  rec_train  \
# 0   0.637221  0.573459   0.381191  0.278900    0.304937   0.216626   0.304937
# 1   0.640777  0.566014   0.388136  0.290271    0.311189   0.208466   0.311189
# 2   0.637239  0.558951   0.394093  0.209979    0.305187   0.202031   0.305187
# 3   0.634566  0.558114   0.380928  0.205674    0.299254   0.202115   0.299254
# 4   0.631530  0.556236   0.387776  0.201742    0.294182   0.204647   0.294182
# 5   0.635762  0.560933   0.395689  0.219232    0.303410   0.210856   0.303410
# 6   0.640262  0.555029   0.404605  0.215796    0.313442   0.205848   0.313442
# 7   0.643590  0.556933   0.408542  0.222317    0.321186   0.195990   0.321186
# 8   0.639410  0.562819   0.405120  0.255211    0.312964   0.203619   0.312964
# 9   0.636501  0.563053   0.394027  0.242027    0.304267   0.202503   0.304267
#
#    rec_test  f1_train   f1_test  \
# 0  0.210288  0.367420  0.233041
# 1  0.204152  0.374799  0.223099
# 2  0.191831  0.365994  0.203646
# 3  0.181029  0.365068  0.199857
# 4  0.169800  0.356111  0.190323
# 5  0.184288  0.367114  0.214964
# 6  0.171754  0.385574  0.204948
# 7  0.177203  0.391433  0.190825
# 8  0.191155  0.375139  0.201772
# 9  0.186102  0.369721  0.205670
#
#                                                                                                                                                                                                                                                                  ts_mean_true  \
# 0  fam_target_ori_clayton     0.030864
# fam_target_ori_frank       0.045455
# fam_target_ori_gaussian    0.212682
# fam_target_ori_gumbel      0.332772
# fam_target_ori_indep       0.072952
# fam_target_ori_joe         0.017957
# fam_target_ori_student     0.287318
# dtype: float64
# 1  fam_target_ori_clayton     0.015417
# fam_target_ori_frank       0.041999
# fam_target_ori_gaussian    0.143009
# fam_target_ori_gumbel      0.358320
# fam_target_ori_indep       0.050505
# fam_target_ori_joe         0.017544
# fam_target_ori_student     0.373206
# dtype: float64
# 2  fam_target_ori_clayton     0.027027
# fam_target_ori_frank       0.161123
# fam_target_ori_gaussian    0.306133
# fam_target_ori_gumbel      0.240644
# fam_target_ori_indep       0.092516
# fam_target_ori_joe         0.010395
# fam_target_ori_student     0.162162
# dtype: float64
# 3  fam_target_ori_clayton     0.054205
# fam_target_ori_frank       0.111449
# fam_target_ori_gaussian    0.235562
# fam_target_ori_gumbel      0.372847
# fam_target_ori_indep       0.110436
# fam_target_ori_joe         0.035968
# fam_target_ori_student     0.079534
# dtype: float64
# 4  fam_target_ori_clayton     0.061442
# fam_target_ori_frank       0.212869
# fam_target_ori_gaussian    0.164973
# fam_target_ori_gumbel      0.388002
# fam_target_ori_indep       0.096759
# fam_target_ori_joe         0.017417
# fam_target_ori_student     0.058539
# dtype: float64
# 5  fam_target_ori_clayton     0.026908
# fam_target_ori_frank       0.215704
# fam_target_ori_gaussian    0.235112
# fam_target_ori_gumbel      0.280988
# fam_target_ori_indep       0.109396
# fam_target_ori_joe         0.019850
# fam_target_ori_student     0.112042
# dtype: float64
# 6  fam_target_ori_clayton     0.025896
# fam_target_ori_frank       0.132067
# fam_target_ori_gaussian    0.153215
# fam_target_ori_gumbel      0.429003
# fam_target_ori_indep       0.090203
# fam_target_ori_joe         0.021148
# fam_target_ori_student     0.148468
# dtype: float64
# 7  fam_target_ori_clayton     0.045397
# fam_target_ori_frank       0.203224
# fam_target_ori_gaussian    0.302503
# fam_target_ori_gumbel      0.234196
# fam_target_ori_indep       0.170132
# fam_target_ori_joe         0.010607
# fam_target_ori_student     0.033941
# dtype: float64
# 8  fam_target_ori_clayton     0.054870
# fam_target_ori_frank       0.066780
# fam_target_ori_gaussian    0.169715
# fam_target_ori_gumbel      0.437686
# fam_target_ori_indep       0.113994
# fam_target_ori_joe         0.031476
# fam_target_ori_student     0.125479
# dtype: float64
# 9  fam_target_ori_clayton     0.048930
# fam_target_ori_frank       0.104849
# fam_target_ori_gaussian    0.232416
# fam_target_ori_gumbel      0.396680
# fam_target_ori_indep       0.115771
# fam_target_ori_joe         0.027523
# fam_target_ori_student     0.073831
# dtype: float64
#
#                                                                                                       ts_mean_estim
# 0  0    0.000000
# 1    0.034792
# 2    0.027497
# 3    0.168350
# 4    0.054994
# 5    0.000000
# 6    0.315376
# dtype: float64
# 1  0    0.000000
# 1    0.024455
# 2    0.050505
# 3    0.173312
# 4    0.051568
# 5    0.000000
# 6    0.334397
# dtype: float64
# 2  0    0.000000
# 1    0.022869
# 2    0.050416
# 3    0.229210
# 4    0.067048
# 5    0.000000
# 6    0.251559
# dtype: float64
# 3  0    0.001013
# 1    0.026849
# 2    0.087639
# 3    0.206687
# 4    0.077001
# 5    0.000000
# 6    0.154509
# dtype: float64
# 4  0    0.000000
# 1    0.028544
# 2    0.111756
# 3    0.221093
# 4    0.096759
# 5    0.000000
# 6    0.040155
# dtype: float64
# 5  0    0.000441
# 1    0.058668
# 2    0.077636
# 3    0.283635
# 4    0.099691
# 5    0.000441
# 6    0.027349
# dtype: float64
# 6  0    0.001726
# 1    0.059128
# 2    0.073371
# 3    0.244281
# 4    0.078550
# 5    0.001726
# 6    0.063876
# dtype: float64
# 7  0    0.001273
# 1    0.044972
# 2    0.043700
# 3    0.321171
# 4    0.109037
# 5    0.001697
# 6    0.050064
# dtype: float64
# 8  0    0.000000
# 1    0.084645
# 2    0.108464
# 3    0.253934
# 4    0.129732
# 5    0.000000
# 6    0.015738
# dtype: float64
# 9  0    0.003495
# 1    0.047619
# 2    0.066841
# 3    0.266492
# 4    0.136741
# 5    0.000000
# 6    0.019659
# dtype: float64
#        auc_train   auc_test  acc_train   acc_test  prec_train  prec_test  \
# count  10.000000  10.000000  10.000000  10.000000   10.000000  10.000000
# mean    0.637686   0.561154   0.394011   0.234115    0.307002   0.205270
# std     0.003451   0.005528   0.009767   0.031274    0.007804   0.005657
# min     0.631530   0.555029   0.380928   0.201742    0.294182   0.195990
# 25%     0.635946   0.557228   0.387866   0.211433    0.303624   0.202212
# 50%     0.637230   0.559942   0.394060   0.220774    0.305062   0.204133
# 75%     0.640049   0.562994   0.402376   0.251915    0.312520   0.207812
# max     0.643590   0.573459   0.408542   0.290271    0.321186   0.216626
#
#        rec_train   rec_test   f1_train    f1_test
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.307002   0.186760   0.371837   0.206814
# std     0.007804   0.013101   0.010360   0.013481
# min     0.294182   0.169800   0.356111   0.190323
# 25%     0.303624   0.178160   0.366274   0.200335
# 50%     0.305062   0.185195   0.368570   0.204297
# 75%     0.312520   0.191662   0.375054   0.212641
# max     0.321186   0.210288   0.391433   0.233041

# %%
ax = opt_model_ori_test_scores.plot(figsize=(9,4))

# %%
ax = opt_model_ori_test_scores[['auc_train', 'auc_test']].plot(figsize=(8,4))

# %%
ax = opt_model_ori_test_scores[['acc_train', 'acc_test']].plot(figsize=(8,4), color=['#2ca02c', '#d62728'])

# %%
ax = opt_model_ori_test_scores[['prec_train', 'prec_test']].plot(figsize=(8,4), color=['#9467bd', '#8c564b'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_ori_test_scores[['rec_train', 'rec_test']].plot(figsize=(8,4), color=['#e377c2', '#8c564b'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_ori_test_scores[['f1_train', 'f1_test']].plot(figsize=(8,4), color=['#bcbd22', '#17becf'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
opt_model_ori_test_scores[['ts_mean_true', 'ts_mean_estim']]
# Out:
#                                                                                                                                                                                                                                                                  ts_mean_true  \
# 0  fam_target_ori_clayton     0.030864
# fam_target_ori_frank       0.045455
# fam_target_ori_gaussian    0.212682
# fam_target_ori_gumbel      0.332772
# fam_target_ori_indep       0.072952
# fam_target_ori_joe         0.017957
# fam_target_ori_student     0.287318
# dtype: float64
# 1  fam_target_ori_clayton     0.015417
# fam_target_ori_frank       0.041999
# fam_target_ori_gaussian    0.143009
# fam_target_ori_gumbel      0.358320
# fam_target_ori_indep       0.050505
# fam_target_ori_joe         0.017544
# fam_target_ori_student     0.373206
# dtype: float64
# 2  fam_target_ori_clayton     0.027027
# fam_target_ori_frank       0.161123
# fam_target_ori_gaussian    0.306133
# fam_target_ori_gumbel      0.240644
# fam_target_ori_indep       0.092516
# fam_target_ori_joe         0.010395
# fam_target_ori_student     0.162162
# dtype: float64
# 3  fam_target_ori_clayton     0.054205
# fam_target_ori_frank       0.111449
# fam_target_ori_gaussian    0.235562
# fam_target_ori_gumbel      0.372847
# fam_target_ori_indep       0.110436
# fam_target_ori_joe         0.035968
# fam_target_ori_student     0.079534
# dtype: float64
# 4  fam_target_ori_clayton     0.061442
# fam_target_ori_frank       0.212869
# fam_target_ori_gaussian    0.164973
# fam_target_ori_gumbel      0.388002
# fam_target_ori_indep       0.096759
# fam_target_ori_joe         0.017417
# fam_target_ori_student     0.058539
# dtype: float64
# 5  fam_target_ori_clayton     0.026908
# fam_target_ori_frank       0.215704
# fam_target_ori_gaussian    0.235112
# fam_target_ori_gumbel      0.280988
# fam_target_ori_indep       0.109396
# fam_target_ori_joe         0.019850
# fam_target_ori_student     0.112042
# dtype: float64
# 6  fam_target_ori_clayton     0.025896
# fam_target_ori_frank       0.132067
# fam_target_ori_gaussian    0.153215
# fam_target_ori_gumbel      0.429003
# fam_target_ori_indep       0.090203
# fam_target_ori_joe         0.021148
# fam_target_ori_student     0.148468
# dtype: float64
# 7  fam_target_ori_clayton     0.045397
# fam_target_ori_frank       0.203224
# fam_target_ori_gaussian    0.302503
# fam_target_ori_gumbel      0.234196
# fam_target_ori_indep       0.170132
# fam_target_ori_joe         0.010607
# fam_target_ori_student     0.033941
# dtype: float64
# 8  fam_target_ori_clayton     0.054870
# fam_target_ori_frank       0.066780
# fam_target_ori_gaussian    0.169715
# fam_target_ori_gumbel      0.437686
# fam_target_ori_indep       0.113994
# fam_target_ori_joe         0.031476
# fam_target_ori_student     0.125479
# dtype: float64
# 9  fam_target_ori_clayton     0.048930
# fam_target_ori_frank       0.104849
# fam_target_ori_gaussian    0.232416
# fam_target_ori_gumbel      0.396680
# fam_target_ori_indep       0.115771
# fam_target_ori_joe         0.027523
# fam_target_ori_student     0.073831
# dtype: float64
#
#                                                                                                       ts_mean_estim
# 0  0    0.000000
# 1    0.034792
# 2    0.027497
# 3    0.168350
# 4    0.054994
# 5    0.000000
# 6    0.315376
# dtype: float64
# 1  0    0.000000
# 1    0.024455
# 2    0.050505
# 3    0.173312
# 4    0.051568
# 5    0.000000
# 6    0.334397
# dtype: float64
# 2  0    0.000000
# 1    0.022869
# 2    0.050416
# 3    0.229210
# 4    0.067048
# 5    0.000000
# 6    0.251559
# dtype: float64
# 3  0    0.001013
# 1    0.026849
# 2    0.087639
# 3    0.206687
# 4    0.077001
# 5    0.000000
# 6    0.154509
# dtype: float64
# 4  0    0.000000
# 1    0.028544
# 2    0.111756
# 3    0.221093
# 4    0.096759
# 5    0.000000
# 6    0.040155
# dtype: float64
# 5  0    0.000441
# 1    0.058668
# 2    0.077636
# 3    0.283635
# 4    0.099691
# 5    0.000441
# 6    0.027349
# dtype: float64
# 6  0    0.001726
# 1    0.059128
# 2    0.073371
# 3    0.244281
# 4    0.078550
# 5    0.001726
# 6    0.063876
# dtype: float64
# 7  0    0.001273
# 1    0.044972
# 2    0.043700
# 3    0.321171
# 4    0.109037
# 5    0.001697
# 6    0.050064
# dtype: float64
# 8  0    0.000000
# 1    0.084645
# 2    0.108464
# 3    0.253934
# 4    0.129732
# 5    0.000000
# 6    0.015738
# dtype: float64
# 9  0    0.003495
# 1    0.047619
# 2    0.066841
# 3    0.266492
# 4    0.136741
# 5    0.000000
# 6    0.019659
# dtype: float64

# %% [markdown]
# ### Data for Storage

# %%
results_ori = {'Model': [opt_model_ori],
            'fc_horizon': 0,
            'vif': [vif],
            'auc_tscv_t': [opt_model_ori_tscv_scores.auc_train.mean()],
            'auc_tscv_v': [opt_model_ori_tscv_scores.auc_valid.mean()],
            'auc_train': [opt_model_ori_test_scores.auc_train.mean()],
            'auc_test': [opt_model_ori_test_scores.auc_test.mean()],
               
            'acc_tscv_t': [opt_model_ori_tscv_scores.acc_train.mean()],
            'acc_tscv_v': [opt_model_ori_tscv_scores.acc_valid.mean()],
            'acc_train': [opt_model_ori_test_scores.acc_train.mean()],
            'acc_test': [opt_model_ori_test_scores.acc_test.mean()],
               
            'prec_tscv_t': [opt_model_ori_tscv_scores.prec_train.mean()],
            'prec_tscv_v': [opt_model_ori_tscv_scores.prec_valid.mean()],
            'prec_train': [opt_model_ori_test_scores.prec_train.mean()],
            'prec_test': [opt_model_ori_test_scores.prec_test.mean()],
               
            'rec_tscv_t': [opt_model_ori_tscv_scores.rec_train.mean()],
            'rec_tscv_v': [opt_model_ori_tscv_scores.rec_valid.mean()],
            'rec_train': [opt_model_ori_test_scores.rec_train.mean()],
            'rec_test': [opt_model_ori_test_scores.rec_test.mean()],
               
            'f1_tscv_t': [opt_model_ori_tscv_scores.f1_train.mean()],
            'f1_tscv_v': [opt_model_ori_tscv_scores.f1_valid.mean()],
            'f1_train': [opt_model_ori_test_scores.f1_train.mean()],
            'f1_test': [opt_model_ori_test_scores.f1_test.mean()],
               
            'opt_model': [opt_model_ori.get_params()],
#             'ts_mean_true': opt_model_ori_test_scores.ts_mean_true,
#             'ts_mean_estim': opt_model_ori_test_scores.ts_mean_estim
              }

# %% [markdown]
# ## ----------------------------------------------------------
# ## Predicted Target Model (one year forecast horizon)
# ### Time Series Cross Validation on Default Model

# %%
default_model_scores_hor = cross_validation (data_set, default_model, 'fam_target_hor')
pd.DataFrame(default_model_scores_hor).describe()
# Out:
#        auc_train  auc_valid  acc_train  acc_valid  prec_train  prec_valid  \
# count       10.0  10.000000       10.0  10.000000        10.0   10.000000
# mean         1.0   0.550084        1.0   0.289880         1.0    0.175546
# std          0.0   0.004083        0.0   0.023709         0.0    0.003898
# min          1.0   0.542826        1.0   0.265429         1.0    0.170594
# 25%          1.0   0.546471        1.0   0.272225         1.0    0.172687
# 50%          1.0   0.552373        1.0   0.280787         1.0    0.175293
# 75%          1.0   0.552684        1.0   0.305105         1.0    0.177035
# max          1.0   0.554187        1.0   0.337262         1.0    0.183869
#
#        rec_train  rec_valid  f1_train   f1_valid
# count       10.0  10.000000      10.0  10.000000
# mean         1.0   0.230327       1.0   0.221959
# std          0.0   0.006681       0.0   0.010027
# min          1.0   0.218702       1.0   0.202976
# 25%          1.0   0.224419       1.0   0.217940
# 50%          1.0   0.233458       1.0   0.223348
# 75%          1.0   0.235466       1.0   0.229648
# max          1.0   0.236457       1.0   0.233007

# %%
ax = pd.DataFrame(default_model_scores_hor).plot(figsize=(8,4))

# %% [markdown]
# ### Hyperparameter Optimization with Time Series Cross Validation
# - Bayesian optimization
# - https://scikit-optimize.github.io/stable/auto_examples/bayesian-optimization.html

# %%
# objective function to minimize
def objective(params):
    max_depth, min_samples_split, min_samples_leaf = params
    model = ml_algorithm(max_depth=int(max_depth), min_samples_split=int(min_samples_split), min_samples_leaf=int(min_samples_leaf), random_state=23)
    scores = cross_validation(data_set, model, 'fam_target_hor')
    return -np.mean(scores['auc_valid'])

# perform the optimization
result = gp_minimize(objective, space, n_calls=100, n_random_starts=20, acq_func='EI', acq_optimizer='lbfgs', random_state=23, n_jobs=-1)

# optimal point and function value
print('Optimal point:', result.x)
print('Function value at optimal point:', result.fun)
ax = pd.DataFrame(result.func_vals).plot(figsize=(12,4))
# Out:
# Optimal point: [49, 4, 2]
# Function value at optimal point: -0.5470670747310482

# %% [markdown]
# ### Time Series Cross Validation on Optimal Model

# %%
# ---------------- config opt model -----------------
opt_model_hor = ml_algorithm(max_depth=49, min_samples_split=4, min_samples_leaf=2, random_state=23)

# %%
opt_model_hor_tscv_scores = cross_validation(data_set, opt_model_hor, 'fam_target_hor')
opt_model_hor_tscv_scores = pd.DataFrame(opt_model_hor_tscv_scores)
display(opt_model_hor_tscv_scores)
display(opt_model_hor_tscv_scores.describe())
# Out:
#    auc_train  auc_valid  acc_train  acc_valid  prec_train  prec_valid  \
# 0   0.871735   0.547813   0.807496   0.276316    0.746809    0.176825
# 1   0.865129   0.555741   0.801031   0.308081    0.733377    0.176037
# 2   0.861546   0.537981   0.805810   0.216374    0.726452    0.171807
# 3   0.858580   0.547526   0.801450   0.238046    0.720449    0.183050
# 4   0.865945   0.539496   0.807532   0.229990    0.735336    0.170775
# 5   0.859320   0.554662   0.801969   0.259313    0.722288    0.177552
# 6   0.862978   0.549811   0.800406   0.241729    0.729348    0.173329
# 7   0.858523   0.542635   0.800285   0.230470    0.720515    0.175607
# 8   0.861486   0.544555   0.804846   0.256258    0.726874    0.170692
# 9   0.858065   0.550452   0.794134   0.274351    0.719457    0.176913
#
#    rec_train  rec_valid  f1_train  f1_valid
# 0   0.746809   0.206601  0.838967  0.215866
# 1   0.733377   0.213491  0.829696  0.220597
# 2   0.726452   0.189072  0.821418  0.196044
# 3   0.720449   0.201881  0.818939  0.213541
# 4   0.735336   0.187789  0.829705  0.186347
# 5   0.722288   0.211740  0.818504  0.228422
# 6   0.729348   0.205890  0.826190  0.218853
# 7   0.720515   0.190055  0.817787  0.192229
# 8   0.726874   0.194117  0.820927  0.200690
# 9   0.719457   0.204532  0.819286  0.216197
#        auc_train  auc_valid  acc_train  acc_valid  prec_train  prec_valid  \
# count  10.000000  10.000000  10.000000  10.000000   10.000000   10.000000
# mean    0.862331   0.547067   0.802496   0.253093    0.728090    0.175259
# std     0.004306   0.005949   0.004077   0.027514    0.008567    0.003778
# min     0.858065   0.537981   0.794134   0.216374    0.719457    0.170692
# 25%     0.858765   0.543115   0.800562   0.232364    0.720958    0.172187
# 50%     0.861516   0.547669   0.801709   0.248994    0.726663    0.175822
# 75%     0.864591   0.550292   0.805569   0.270592    0.732370    0.176891
# max     0.871735   0.555741   0.807532   0.308081    0.746809    0.183050
#
#        rec_train  rec_valid   f1_train   f1_valid
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.728090   0.200517   0.824142   0.208878
# std     0.008567   0.009554   0.006883   0.013982
# min     0.719457   0.187789   0.817787   0.186347
# 25%     0.720958   0.191070   0.819026   0.197206
# 50%     0.726663   0.203206   0.821172   0.214704
# 75%     0.732370   0.206423   0.828820   0.218189
# max     0.746809   0.213491   0.838967   0.228422

# %%
ax = opt_model_hor_tscv_scores.plot(figsize=(9,5))

# %%
ax = opt_model_hor_tscv_scores[['auc_train', 'auc_valid']].plot(figsize=(8,4))
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_hor_tscv_scores[['acc_train', 'acc_valid']].plot(figsize=(8,4), color=['#2ca02c', '#d62728'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_hor_tscv_scores[['prec_train', 'prec_valid']].plot(figsize=(8,4), color=['#9467bd', '#8c564b'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_hor_tscv_scores[['rec_train', 'rec_valid']].plot(figsize=(8,4), color=['#e377c2', '#8c564b'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_hor_tscv_scores[['f1_train', 'f1_valid']].plot(figsize=(8,4), color=['#bcbd22', '#17becf'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %% [markdown]
# ### Model Performance on Test Set

# %%
opt_model_hor_test_scores = performance_test_shifted(data_set, opt_model_hor, 'fam_target_hor')
opt_model_hor_test_scores = pd.DataFrame(opt_model_hor_test_scores)
display(opt_model_hor_test_scores)
display(opt_model_hor_test_scores.describe())
# Out:
#    auc_train  auc_test  acc_train  acc_test  prec_train  prec_test  rec_train  \
# 0   0.860725  0.545226   0.798472  0.296296    0.724841   0.170065   0.724841
# 1   0.862415  0.538399   0.805973  0.230197    0.728343   0.168400   0.728343
# 2   0.868484  0.543245   0.802992  0.228690    0.740045   0.183591   0.740045
# 3   0.864096  0.544125   0.804931  0.241135    0.731432   0.169772   0.731432
# 4   0.860782  0.546423   0.801312  0.231737    0.725033   0.174654   0.725033
# 5   0.863433  0.545660   0.803375  0.253639    0.730555   0.174517   0.730555
# 6   0.859051  0.546850   0.799315  0.235650    0.721633   0.180389   0.721633
# 7   0.858218  0.541739   0.798688  0.257531    0.719717   0.173130   0.719717
# 8   0.859828  0.542377   0.799505  0.265419    0.723012   0.172820   0.723012
# 9   0.860609  0.533116   0.799630  0.171691    0.724819   0.147930   0.724819
#
#    rec_test  f1_train   f1_test  \
# 0  0.193532  0.821779  0.200437
# 1  0.184038  0.823822  0.184213
# 2  0.195648  0.833617  0.205313
# 3  0.195710  0.826433  0.199687
# 4  0.202739  0.822345  0.218915
# 5  0.200303  0.825047  0.212358
# 6  0.196380  0.819883  0.195309
# 7  0.188091  0.818413  0.199631
# 8  0.190147  0.820707  0.205037
# 9  0.181843  0.822226  0.105007
#
#                                                                                                                                                                                                                                                                  ts_mean_true  \
# 0  fam_target_hor_clayton     0.015152
# fam_target_hor_frank       0.042088
# fam_target_hor_gaussian    0.143098
# fam_target_hor_gumbel      0.356341
# fam_target_hor_indep       0.049944
# fam_target_hor_joe         0.016274
# fam_target_hor_student     0.377104
# dtype: float64
# 1  fam_target_hor_clayton     0.022860
# fam_target_hor_frank       0.162148
# fam_target_hor_gaussian    0.307283
# fam_target_hor_gumbel      0.243488
# fam_target_hor_indep       0.086656
# fam_target_hor_joe         0.010633
# fam_target_hor_student     0.166932
# dtype: float64
# 2  fam_target_hor_clayton     0.051455
# fam_target_hor_frank       0.111746
# fam_target_hor_gaussian    0.235447
# fam_target_hor_gumbel      0.373181
# fam_target_hor_indep       0.102911
# fam_target_hor_joe         0.040021
# fam_target_hor_student     0.085239
# dtype: float64
# 3  fam_target_hor_clayton     0.057244
# fam_target_hor_frank       0.211246
# fam_target_hor_gaussian    0.165147
# fam_target_hor_gumbel      0.397670
# fam_target_hor_indep       0.093212
# fam_target_hor_joe         0.017224
# fam_target_hor_student     0.058257
# dtype: float64
# 4  fam_target_hor_clayton     0.025157
# fam_target_hor_frank       0.210450
# fam_target_hor_gaussian    0.241413
# fam_target_hor_gumbel      0.283986
# fam_target_hor_indep       0.100629
# fam_target_hor_joe         0.021771
# fam_target_hor_student     0.116594
# dtype: float64
# 5  fam_target_hor_clayton     0.027790
# fam_target_hor_frank       0.132333
# fam_target_hor_gaussian    0.154830
# fam_target_hor_gumbel      0.432289
# fam_target_hor_indep       0.084693
# fam_target_hor_joe         0.020732
# fam_target_hor_student     0.147331
# dtype: float64
# 6  fam_target_hor_clayton     0.047044
# fam_target_hor_frank       0.205006
# fam_target_hor_gaussian    0.300388
# fam_target_hor_gumbel      0.247734
# fam_target_hor_indep       0.156237
# fam_target_hor_joe         0.008632
# fam_target_hor_student     0.034959
# dtype: float64
# 7  fam_target_hor_clayton     0.052185
# fam_target_hor_frank       0.069156
# fam_target_hor_gaussian    0.165040
# fam_target_hor_gumbel      0.440815
# fam_target_hor_indep       0.108613
# fam_target_hor_joe         0.033941
# fam_target_hor_student     0.130250
# dtype: float64
# 8  fam_target_hor_clayton     0.051042
# fam_target_hor_frank       0.107188
# fam_target_hor_gaussian    0.227988
# fam_target_hor_gumbel      0.399830
# fam_target_hor_indep       0.113569
# fam_target_hor_joe         0.027222
# fam_target_hor_student     0.073160
# dtype: float64
# 9  fam_target_hor_clayton     0.013106
# fam_target_hor_frank       0.007864
# fam_target_hor_gaussian    0.029270
# fam_target_hor_gumbel      0.363478
# fam_target_hor_indep       0.015291
# fam_target_hor_joe         0.083006
# fam_target_hor_student     0.487986
# dtype: float64
#
#                                                                                                       ts_mean_estim
# 0  0    0.011223
# 1    0.066779
# 2    0.139731
# 3    0.244669
# 4    0.061167
# 5    0.010662
# 6    0.292929
# dtype: float64
# 1  0    0.009038
# 1    0.045189
# 2    0.114301
# 3    0.263690
# 4    0.051568
# 5    0.006380
# 6    0.336523
# dtype: float64
# 2  0    0.014033
# 1    0.064449
# 2    0.187630
# 3    0.251559
# 4    0.066528
# 5    0.008316
# 6    0.234407
# dtype: float64
# 3  0    0.017224
# 1    0.084093
# 2    0.180344
# 3    0.282675
# 4    0.070415
# 5    0.014691
# 6    0.181864
# dtype: float64
# 4  0    0.022738
# 1    0.097242
# 2    0.145138
# 3    0.331398
# 4    0.076439
# 5    0.018868
# 6    0.143203
# dtype: float64
# 5  0    0.014998
# 1    0.119541
# 2    0.178209
# 3    0.286723
# 4    0.082488
# 5    0.014557
# 6    0.134980
# dtype: float64
# 6  0    0.022443
# 1    0.104877
# 2    0.135520
# 3    0.308157
# 4    0.074234
# 5    0.013379
# 6    0.156668
# dtype: float64
# 7  0    0.025456
# 1    0.122189
# 2    0.194315
# 3    0.279168
# 4    0.101824
# 5    0.009758
# 6    0.089096
# dtype: float64
# 8  0    0.028924
# 1    0.101234
# 2    0.175245
# 3    0.323267
# 4    0.105062
# 5    0.012335
# 6    0.073586
# dtype: float64
# 9  0    0.035387
# 1    0.093054
# 2    0.179118
# 3    0.346003
# 4    0.108344
# 5    0.013543
# 6    0.051114
# dtype: float64
#        auc_train   auc_test  acc_train   acc_test  prec_train  prec_test  \
# count  10.000000  10.000000  10.000000  10.000000   10.000000  10.000000
# mean    0.861764   0.542716   0.801419   0.241198    0.726943   0.171527
# std     0.002998   0.004215   0.002725   0.032099    0.005919   0.009539
# min     0.858218   0.533116   0.798472   0.171691    0.719717   0.147930
# 25%     0.860023   0.541898   0.799363   0.230582    0.723464   0.169845
# 50%     0.860754   0.543685   0.800471   0.238392    0.724937   0.172975
# 75%     0.863178   0.545551   0.803279   0.256558    0.730002   0.174620
# max     0.868484   0.546850   0.805973   0.296296    0.740045   0.183591
#
#        rec_train   rec_test   f1_train    f1_test
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.726943   0.192843   0.823427   0.192591
# std     0.005919   0.006758   0.004296   0.032164
# min     0.719717   0.181843   0.818413   0.105007
# 25%     0.723464   0.188605   0.820975   0.196390
# 50%     0.724937   0.194590   0.822285   0.200062
# 75%     0.730002   0.196212   0.824741   0.205244
# max     0.740045   0.202739   0.833617   0.218915

# %%
ax = opt_model_hor_test_scores[['auc_train', 'auc_test']].plot(figsize=(8,4))
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_hor_test_scores[['acc_train', 'acc_test']].plot(figsize=(8,4), color=['#2ca02c', '#d62728'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_hor_test_scores[['prec_train', 'prec_test']].plot(figsize=(8,4), color=['#9467bd', '#8c564b'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_hor_test_scores[['rec_train', 'rec_test']].plot(figsize=(8,4), color=['#e377c2', '#8c564b'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
ax = opt_model_hor_test_scores[['f1_train', 'f1_test']].plot(figsize=(8,4), color=['#bcbd22', '#17becf'])
plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
opt_model_hor_test_scores[['ts_mean_true', 'ts_mean_estim']]

# %% [markdown]
# ### Data for Storage

# %%
results_hor = {'Model': [opt_model_ori],
            'fc_horizon': 1,
            'vif': [vif],
            'auc_tscv_t': [opt_model_hor_tscv_scores.auc_train.mean()],
            'auc_tscv_v': [opt_model_hor_tscv_scores.auc_valid.mean()],
            'auc_train': [opt_model_hor_test_scores.auc_train.mean()],
            'auc_test': [opt_model_hor_test_scores.auc_test.mean()],
               
            'acc_tscv_t': [opt_model_hor_tscv_scores.acc_train.mean()],
            'acc_tscv_v': [opt_model_hor_tscv_scores.acc_valid.mean()],
            'acc_train': [opt_model_hor_test_scores.acc_train.mean()],
            'acc_test': [opt_model_hor_test_scores.acc_test.mean()],
               
            'prec_tscv_t': [opt_model_hor_tscv_scores.prec_train.mean()],
            'prec_tscv_v': [opt_model_hor_tscv_scores.prec_valid.mean()],
            'prec_train': [opt_model_hor_test_scores.prec_train.mean()],
            'prec_test': [opt_model_hor_test_scores.prec_test.mean()],
               
            'rec_tscv_t': [opt_model_hor_tscv_scores.rec_train.mean()],
            'rec_tscv_v': [opt_model_hor_tscv_scores.rec_valid.mean()],
            'rec_train': [opt_model_hor_test_scores.rec_train.mean()],
            'rec_test': [opt_model_hor_test_scores.rec_test.mean()],
               
            'f1_tscv_t': [opt_model_hor_tscv_scores.f1_train.mean()],
            'f1_tscv_v': [opt_model_hor_tscv_scores.f1_valid.mean()],
            'f1_train': [opt_model_hor_test_scores.f1_train.mean()],
            'f1_test': [opt_model_hor_test_scores.f1_test.mean()],
               
            'opt_model': [opt_model_ori.get_params()],
#             'ts_mean_true': opt_model_ori_test_scores.ts_mean_true,
#             'ts_mean_estim': opt_model_ori_test_scores.ts_mean_estim
              }

# %% [markdown]
# ## Safe to Excel

# %%
results = pd.concat([pd.DataFrame(results_ori), pd.DataFrame(results_hor)])

display(results)

storage_name = filename + '_' + vif + '_' + str(datetime.today().day) + '.xlsx'

pd.DataFrame(results).to_excel(path + 'artifacts' + slash + storage_name, index=None)
# Out:
#                                                                                                                       Model  \
# 0  DecisionTreeClassifier(max_depth=35, min_samples_leaf=17, min_samples_split=12,\n                       random_state=23)
# 0  DecisionTreeClassifier(max_depth=35, min_samples_leaf=17, min_samples_split=12,\n                       random_state=23)
#
#    fc_horizon     vif  auc_tscv_t  auc_tscv_v  auc_train  auc_test  \
# 0           0  vif_10    0.640866    0.562902   0.637686  0.561154
# 0           1  vif_10    0.862331    0.547067   0.861764  0.542716
#
#    acc_tscv_t  acc_tscv_v  acc_train  acc_test  prec_tscv_t  prec_tscv_v  \
# 0    0.400131    0.243688   0.394011  0.234115     0.314113     0.205020
# 0    0.802496    0.253093   0.801419  0.241198     0.728090     0.175259
#
#    prec_train  prec_test  rec_tscv_t  rec_tscv_v  rec_train  rec_test  \
# 0    0.307002   0.205270    0.314113    0.192535   0.307002  0.186760
# 0    0.726943   0.171527    0.728090    0.200517   0.726943  0.192843
#
#    f1_tscv_t  f1_tscv_v  f1_train   f1_test  \
# 0   0.378893   0.212740  0.371837  0.206814
# 0   0.824142   0.208878  0.823427  0.192591
#
#                                                                                                                                                                                                                                                                               opt_model
# 0  {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 35, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 17, 'min_samples_split': 12, 'min_weight_fraction_leaf': 0.0, 'random_state': 23, 'splitter': 'best'}
# 0  {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 35, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 17, 'min_samples_split': 12, 'min_weight_fraction_leaf': 0.0, 'random_state': 23, 'splitter': 'best'}
