# %% [markdown]
# # K Neares Neighbor (tau) [vif5]
# Regression based on k-nearest neighbors.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsRegressor.html
#
# KNeighborsRegressor()
#
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 5,
#  'p': 2,
#  'weights': 'uniform'}
#
# **_bayesian hyperparameter tuning_**

# %%
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pathlib
import platform
import seaborn as sns
from sklearn import linear_model
from sklearn import tree
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from skopt import gp_minimize, space
from skopt.space import Real, Integer
import sys

from validation import cross_validation
from validation import performance_test_shifted

date_format = '%Y-%m-%d'

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.max_colwidth = None

# %%
# config 'all', 'vif_5' or 'vif_10'
vif = 'vif_5'

# config model
ml_algorithm = KNeighborsRegressor
filename = 'single-model_tau_knn'

# %%
my_os = platform.system()
print('OS in my system: ',my_os)

if my_os == 'Windows':
    path = str(pathlib.Path().absolute()) + '\\'
    slash = '\\'
else:
    path = str(pathlib.Path().absolute()) + '/'
    slash = '/'

path_3 = path.replace('4_modelling', '3_data_pre-processing')
# Out:
# OS in my system:  Linux

# %% [markdown]
# ## Load Data

# %%
data_set = pd.read_csv(path_3 + 'data_artifacts' + slash + 'data_set_e_spx_3-' + vif + '.csv', index_col=0)

# %% [markdown]
# ## Original Target Model (no forecast horizon)
# ### Time Series Cross Validation on Default Model

# %%
default_model = ml_algorithm()
default_model.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 5,
#  'p': 2,
#  'weights': 'uniform'}

# %%
default_model_scores_ori = cross_validation (data_set, default_model, 'tau_target_ori')
pd.DataFrame(default_model_scores_ori).describe()
# Out:
#        mse_train  mse_valid  mae_train  mae_valid   r2_train   r2_valid
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.006932   0.014078   0.065012   0.094703   0.751202   0.376958
# std     0.000495   0.005003   0.002615   0.019535   0.013339   0.281912
# min     0.006149   0.008541   0.061105   0.071942   0.733114  -0.367604
# 25%     0.006562   0.010181   0.063456   0.079707   0.742896   0.396805
# 50%     0.006919   0.012905   0.064688   0.090316   0.749230   0.441887
# 75%     0.007404   0.017735   0.067278   0.110657   0.753979   0.515361
# max     0.007575   0.023162   0.068579   0.127219   0.776262   0.599001

# %%
ax = pd.DataFrame(default_model_scores_ori).plot(figsize=(8,4))

# %% [markdown]
# ### Hyperparameter Optimization with Time Series Cross Validation
# - Bayesian optimization
# - https://scikit-optimize.github.io/stable/auto_examples/bayesian-optimization.html

# %%
# search space for the hyperparameters
space = [Integer(1, 30, name='n_neighbors'),
         Integer(1, 50, name='leaf_size'),
         Integer(1, 2, name='p')]

# %%
# objective function to minimize
def objective(params):
    n_neighbors, leaf_size, p = params
    model = ml_algorithm(n_neighbors=int(n_neighbors), leaf_size=int(leaf_size), p=int(p))
    scores = cross_validation(data_set, model, 'tau_target_ori')
    return np.mean(scores['mse_valid'])

# perform the optimization
result = gp_minimize(objective, space, n_calls=100, n_random_starts=20, acq_func='EI', acq_optimizer='auto', random_state=23, n_jobs=-1)

# optimal point and function value
print('Optimal point:', result.x)
print('Function value at optimal point:', result.fun)
ax = pd.DataFrame(result.func_vals).plot(figsize=(12,4))
# Out:
# /home/sc.uni-leipzig.de/ae085wyju/.local/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Optimal point: [4, 36, 1]
# Function value at optimal point: 0.012030004557513466

# %% [markdown]
# ### Time Series Cross Validation on Optimal Model

# %%
# ---------------- config opt model -----------------
opt_model_ori = ml_algorithm(n_neighbors=4, leaf_size=36, p=1)

# %%
opt_model_ori_tscv_scores = cross_validation(data_set, opt_model_ori, 'tau_target_ori')
opt_model_ori_tscv_scores = pd.DataFrame(opt_model_ori_tscv_scores)
display(opt_model_ori_tscv_scores)
display(opt_model_ori_tscv_scores.describe())
# Out:
#    mse_train  mse_valid  mae_train  mae_valid  r2_train  r2_valid
# 0   0.004954   0.019941   0.054120   0.115730  0.797509  0.347411
# 1   0.005119   0.010753   0.055330   0.081484  0.808660  0.600834
# 2   0.004977   0.016779   0.054429   0.108132  0.818745  0.493892
# 3   0.005390   0.012058   0.056747   0.089557  0.819774  0.541021
# 4   0.005663   0.011680   0.059200   0.087153  0.809758  0.467349
# 5   0.005901   0.009942   0.060923   0.079204  0.798139  0.482704
# 6   0.005399   0.007675   0.057979   0.068353  0.810233  0.680556
# 7   0.004888   0.006868   0.054836   0.064100  0.828493  0.666335
# 8   0.004596   0.016501   0.052826   0.106384  0.832786 -0.170408
# 9   0.005048   0.008105   0.055635   0.071298  0.811485  0.567000
#        mse_train  mse_valid  mae_train  mae_valid   r2_train   r2_valid
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.005193   0.012030   0.056202   0.087140   0.813558   0.467669
# std     0.000392   0.004375   0.002507   0.017839   0.011583   0.245014
# min     0.004596   0.006868   0.052826   0.064100   0.797509  -0.170408
# 25%     0.004960   0.008564   0.054531   0.073274   0.808934   0.471188
# 50%     0.005084   0.011216   0.055482   0.084318   0.810859   0.517456
# 75%     0.005397   0.015390   0.057671   0.102178   0.819517   0.592375
# max     0.005901   0.019941   0.060923   0.115730   0.832786   0.680556

# %%
ax = opt_model_ori_tscv_scores[['mse_train', 'mse_valid', 'mae_train', 'mae_valid', 'r2_train', 'r2_valid']].plot(figsize=(8,4))

# %%
ax = opt_model_ori_tscv_scores[['mse_train', 'mse_valid']].plot(figsize=(8,4))

# %%
ax = opt_model_ori_tscv_scores[['mae_train', 'mae_valid']].plot(figsize=(8,4), color=['#2ca02c', '#d62728'])

# %%
ax = opt_model_ori_tscv_scores[['r2_train', 'r2_valid']].plot(figsize=(8,4), color=['#9467bd', '#8c564b'])

# %% [markdown]
# ### Model Performance on Test Set

# %%
opt_model_ori_test_scores = performance_test_shifted(data_set, opt_model_ori, 'tau_target_ori')
opt_model_ori_test_scores = pd.DataFrame(opt_model_ori_test_scores)
display(opt_model_ori_test_scores)
display(opt_model_ori_test_scores.describe())
# Out:
#    mse_train  mse_test  mae_train  mae_test  r2_train   r2_test  ts_mean_true  \
# 0   0.005411  0.011003   0.056722  0.082016  0.796824  0.591523      0.366445
# 1   0.004851  0.016778   0.053835  0.108601  0.822557  0.493916      0.425448
# 2   0.005262  0.011899   0.056058  0.088839  0.823522  0.547072      0.330819
# 3   0.005532  0.011484   0.058224  0.086141  0.811845  0.476290      0.286654
# 4   0.005653  0.009700   0.059418  0.078370  0.805585  0.495264      0.281294
# 5   0.005588  0.007567   0.058909  0.067898  0.802683  0.685039      0.288558
# 6   0.004966  0.006667   0.055355  0.063109  0.823744  0.676070      0.291026
# 7   0.004562  0.016737   0.052664  0.107261  0.835180 -0.187094      0.199579
# 8   0.005144  0.008287   0.055956  0.071999  0.813561  0.557262      0.245124
# 9   0.004849  0.006583   0.054501  0.062442  0.814597  0.683632      0.245513
#
#    ts_mean_estim
# 0       0.320555
# 1       0.342157
# 2       0.367110
# 3       0.355176
# 4       0.331648
# 5       0.316951
# 6       0.307639
# 7       0.297967
# 8       0.272717
# 9       0.260175
#        mse_train   mse_test  mae_train   mae_test   r2_train    r2_test  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.005182   0.010671   0.056164   0.081668   0.815010   0.501897
# std     0.000368   0.003732   0.002207   0.016533   0.011529   0.255063
# min     0.004562   0.006583   0.052664   0.062442   0.796824  -0.187094
# 25%     0.004880   0.007747   0.054714   0.068924   0.807150   0.494253
# 50%     0.005203   0.010352   0.056007   0.080193   0.814079   0.552167
# 75%     0.005502   0.011795   0.057849   0.088164   0.823281   0.654934
# max     0.005653   0.016778   0.059418   0.108601   0.835180   0.685039
#
#        ts_mean_true  ts_mean_estim
# count     10.000000      10.000000
# mean       0.296046       0.317209
# std        0.064764       0.034105
# min        0.199579       0.260175
# 25%        0.254458       0.300385
# 50%        0.287606       0.318753
# 75%        0.320871       0.339530
# max        0.425448       0.367110

# %%
ax = opt_model_ori_test_scores.plot(figsize=(8,4))

# %%
ax = opt_model_ori_test_scores[['mse_train', 'mse_test']].plot(figsize=(8,4))

# %%
ax = opt_model_ori_test_scores[['mae_train', 'mae_test']].plot(figsize=(8,4), color=['#2ca02c', '#d62728'])

# %%
ax = opt_model_ori_test_scores[['r2_train', 'r2_test']].plot(figsize=(8,4), color=['#9467bd', '#8c564b'])

# %%
ax = opt_model_ori_test_scores[['ts_mean_true', 'ts_mean_estim']].plot(figsize=(8,4), color=['#e377c2', '#8c564b'])
plt.ylim([0.2,0.45])
# Out:
# (0.2, 0.45)

# %% [markdown]
# ### Data for Storage

# %%
results_ori = {'Model': [opt_model_ori],
            'fc_horizon': 0,
            'vif': [vif],
            'mse_tscv_t': [opt_model_ori_tscv_scores.mse_train.mean()],
            'mse_tscv_v': [opt_model_ori_tscv_scores.mse_valid.mean()],
            'mse_train': [opt_model_ori_test_scores.mse_train.mean()],
            'mse_test': [opt_model_ori_test_scores.mse_test.mean()],
               
            'mae_tscv_t': [opt_model_ori_tscv_scores.mae_train.mean()],
            'mae_tscv_v': [opt_model_ori_tscv_scores.mae_valid.mean()],
            'mae_train': [opt_model_ori_test_scores.mae_train.mean()],
            'mae_test': [opt_model_ori_test_scores.mae_test.mean()],
               
            'r2_tscv_t': [opt_model_ori_tscv_scores.r2_train.mean()],
            'r2_tscv_v': [opt_model_ori_tscv_scores.r2_valid.mean()],
            'r2_train': [opt_model_ori_test_scores.r2_train.mean()],
            'r2_test': [opt_model_ori_test_scores.r2_test.mean()],
               
            'opt_model': [opt_model_ori.get_params()],
            'ts_mean_true': opt_model_ori_test_scores.ts_mean_true.mean(),
            'ts_mean_estim': opt_model_ori_test_scores.ts_mean_estim.mean(),
              }

# %% [markdown]
# ## ----------------------------------------------------------
# ## Predicted Target Model (one year forecast horizon)
# ### Time Series Cross Validation on Default Model

# %%
default_model_scores_hor = cross_validation (data_set, default_model, 'tau_target_hor')
pd.DataFrame(default_model_scores_hor).describe()
# Out:
#        mse_train  mse_valid  mae_train  mae_valid   r2_train   r2_valid
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.007150   0.013407   0.066051   0.091790   0.740426   0.370024
# std     0.000516   0.004687   0.002681   0.018758   0.010255   0.309641
# min     0.006498   0.008527   0.062616   0.071407   0.730466  -0.472923
# 25%     0.006729   0.009930   0.063953   0.077510   0.732695   0.358671
# 50%     0.007004   0.012463   0.065277   0.088417   0.737793   0.448660
# 75%     0.007668   0.014738   0.068457   0.097674   0.742539   0.523408
# max     0.007889   0.022291   0.069962   0.125242   0.759075   0.586654

# %%
ax = pd.DataFrame(default_model_scores_hor).plot(figsize=(8,4))

# %% [markdown]
# ### Hyperparameter Optimization with Time Series Cross Validation
# - Bayesian optimization
# - https://scikit-optimize.github.io/stable/auto_examples/bayesian-optimization.html

# %%
# objective function to minimize
def objective(params):
    n_neighbors, leaf_size, p = params
    model = ml_algorithm(n_neighbors=int(n_neighbors), leaf_size=int(leaf_size), p=int(p))
    scores = cross_validation(data_set, model, 'tau_target_hor')
    return np.mean(scores['mse_valid'])

# perform the optimization
result = gp_minimize(objective, space, n_calls=100, n_random_starts=20, acq_func='EI', acq_optimizer='auto', random_state=23, n_jobs=-1)

# optimal point and function value
print('Optimal point:', result.x)
print('Function value at optimal point:', result.fun)
ax = pd.DataFrame(result.func_vals).plot(figsize=(12,4))
# Out:
# Optimal point: [4, 36, 1]
# Function value at optimal point: 0.011774955360321764

# %% [markdown]
# ### Time Series Cross Validation on Optimal Model

# %%
# ---------------- config opt model -----------------
opt_model_hor = ml_algorithm(n_neighbors=4, leaf_size=36, p=1)

# %%
opt_model_hor_tscv_scores = cross_validation(data_set, opt_model_hor, 'tau_target_hor')
opt_model_hor_tscv_scores = pd.DataFrame(opt_model_hor_tscv_scores)
display(opt_model_hor_tscv_scores)
display(opt_model_hor_tscv_scores.describe())
# Out:
#    mse_train  mse_valid  mae_train  mae_valid  r2_train  r2_valid
# 0   0.005039   0.012933   0.054958   0.089133  0.806150  0.524806
# 1   0.005216   0.019147   0.055872   0.114473  0.805751  0.425719
# 2   0.005783   0.013754   0.058722   0.094948  0.803775  0.464256
# 3   0.006168   0.011786   0.061734   0.087997  0.790224  0.452820
# 4   0.006289   0.011240   0.062782   0.084224  0.782199  0.411023
# 5   0.005741   0.007965   0.059893   0.069408  0.796188  0.662844
# 6   0.005210   0.007450   0.056216   0.067239  0.814863  0.625623
# 7   0.004951   0.017968   0.054601   0.113520  0.816416 -0.299209
# 8   0.005506   0.008513   0.058025   0.073285  0.791313  0.542997
# 9   0.005360   0.006993   0.056918   0.064027  0.786748  0.661024
#        mse_train  mse_valid  mae_train  mae_valid   r2_train   r2_valid
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.005526   0.011775   0.057972   0.085825   0.799363   0.447190
# std     0.000459   0.004281   0.002801   0.018063   0.011783   0.278583
# min     0.004951   0.006993   0.054601   0.064027   0.782199  -0.299209
# 25%     0.005212   0.008102   0.055958   0.070377   0.790496   0.432494
# 50%     0.005433   0.011513   0.057472   0.086111   0.799981   0.494531
# 75%     0.005773   0.013549   0.059600   0.093494   0.806050   0.604967
# max     0.006289   0.019147   0.062782   0.114473   0.816416   0.662844

# %%
ax = opt_model_hor_tscv_scores[['mse_train', 'mse_valid', 'mae_train', 'mae_valid', 'r2_train', 'r2_valid']].plot(figsize=(8,4))

# %%
ax = opt_model_hor_tscv_scores[['mse_train', 'mse_valid']].plot(figsize=(8,4))

# %%
ax = opt_model_hor_tscv_scores[['mae_train', 'mae_valid']].plot(figsize=(8,4), color=['#2ca02c', '#d62728'])

# %%
ax = opt_model_hor_tscv_scores[['r2_train', 'r2_valid']].plot(figsize=(8,4), color=['#9467bd', '#8c564b'])

# %% [markdown]
# ### Model Performance on Test Set

# %%
opt_model_hor_test_scores = performance_test_shifted(data_set, opt_model_hor, 'tau_target_hor')
opt_model_hor_test_scores = pd.DataFrame(opt_model_hor_test_scores)
display(opt_model_hor_test_scores)
display(opt_model_hor_test_scores.describe())
# Out:
#    mse_train  mse_test  mae_train  mae_test  r2_train   r2_test  ts_mean_true  \
# 0   0.005084  0.019399   0.055063  0.115421  0.809403  0.418175      0.429797
# 1   0.005643  0.013516   0.058024  0.094135  0.807740  0.473527      0.335499
# 2   0.005941  0.011488   0.060361  0.086841  0.794605  0.466668      0.293080
# 3   0.006031  0.011050   0.061189  0.083120  0.789530  0.421018      0.287144
# 4   0.005972  0.007829   0.060869  0.068937  0.786351  0.668601      0.295090
# 5   0.005350  0.007354   0.057053  0.067018  0.807934  0.630460      0.292463
# 6   0.004897  0.018344   0.054257  0.114655  0.820476 -0.326403      0.205042
# 7   0.005518  0.008760   0.058158  0.074298  0.796115  0.529776      0.247086
# 8   0.005244  0.007150   0.056684  0.064665  0.796727  0.653393      0.248710
# 9   0.005043  0.014756   0.054928  0.101412  0.796577  0.208965      0.342639
#
#    ts_mean_estim
# 0       0.338394
# 1       0.374390
# 2       0.361282
# 3       0.346171
# 4       0.325827
# 5       0.317665
# 6       0.311505
# 7       0.277162
# 8       0.267683
# 9       0.258098
#        mse_train   mse_test  mae_train   mae_test   r2_train    r2_test  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.005472   0.011964   0.057659   0.087050   0.800546   0.414418
# std     0.000415   0.004460   0.002529   0.018950   0.010489   0.294205
# min     0.004897   0.007150   0.054257   0.064665   0.786351  -0.326403
# 25%     0.005124   0.008061   0.055468   0.070277   0.794982   0.418886
# 50%     0.005434   0.011269   0.057539   0.084981   0.796652   0.470097
# 75%     0.005867   0.014446   0.059810   0.099593   0.807886   0.605289
# max     0.006031   0.019399   0.061189   0.115421   0.820476   0.668601
#
#        ts_mean_true  ts_mean_estim
# count     10.000000      10.000000
# mean       0.297655       0.317818
# std        0.062015       0.039656
# min        0.205042       0.258098
# 25%        0.258318       0.285747
# 50%        0.292772       0.321746
# 75%        0.325397       0.344227
# max        0.429797       0.374390

# %%
ax = opt_model_hor_test_scores.plot(figsize=(8,4))

# %%
ax = opt_model_hor_test_scores[['mse_train', 'mse_test']].plot(figsize=(8,4))

# %%
ax = opt_model_hor_test_scores[['mae_train', 'mae_test']].plot(figsize=(8,4), color=['#2ca02c', '#d62728'])

# %%
ax = opt_model_hor_test_scores[['r2_train', 'r2_test']].plot(figsize=(8,4), color=['#9467bd', '#8c564b'])

# %%
ax = opt_model_hor_test_scores[['ts_mean_true', 'ts_mean_estim']].plot(figsize=(8,4), color=['#e377c2', '#8c564b'])
plt.ylim([0.2,0.45])
# Out:
# (0.2, 0.45)

# %% [markdown]
# ### Data for Storage

# %%
results_hor = {'Model': [opt_model_ori],
            'fc_horizon': 1,
            'vif': [vif],
            'mse_tscv_t': [opt_model_hor_tscv_scores.mse_train.mean()],
            'mse_tscv_v': [opt_model_hor_tscv_scores.mse_valid.mean()],
            'mse_train': [opt_model_hor_test_scores.mse_train.mean()],
            'mse_test': [opt_model_hor_test_scores.mse_test.mean()],
               
            'mae_tscv_t': [opt_model_hor_tscv_scores.mae_train.mean()],
            'mae_tscv_v': [opt_model_hor_tscv_scores.mae_valid.mean()],
            'mae_train': [opt_model_hor_test_scores.mae_train.mean()],
            'mae_test': [opt_model_hor_test_scores.mae_test.mean()],
               
            'r2_tscv_t': [opt_model_hor_tscv_scores.r2_train.mean()],
            'r2_tscv_v': [opt_model_hor_tscv_scores.r2_valid.mean()],
            'r2_train': [opt_model_hor_test_scores.r2_train.mean()],
            'r2_test': [opt_model_hor_test_scores.r2_test.mean()],
               
            'opt_model': [opt_model_hor.get_params()],
            'ts_mean_true': opt_model_hor_test_scores.ts_mean_true.mean(),
            'ts_mean_estim': opt_model_hor_test_scores.ts_mean_estim.mean(),
              }

# %% [markdown]
# ## Safe to Excel

# %%
results = pd.concat([pd.DataFrame(results_ori), pd.DataFrame(results_hor)])

display(results)

storage_name = filename + '_' + vif + '_' + str(datetime.today().day) + '.xlsx'

pd.DataFrame(results).to_excel(path + 'artifacts' + slash + storage_name, index=None)
# Out:
#                                                    Model  fc_horizon    vif  \
# 0  KNeighborsRegressor(leaf_size=36, n_neighbors=4, p=1)           0  vif_5
# 0  KNeighborsRegressor(leaf_size=36, n_neighbors=4, p=1)           1  vif_5
#
#    mse_tscv_t  mse_tscv_v  mse_train  mse_test  mae_tscv_t  mae_tscv_v  \
# 0    0.005193    0.012030   0.005182  0.010671    0.056202    0.087140
# 0    0.005526    0.011775   0.005472  0.011964    0.057972    0.085825
#
#    mae_train  mae_test  r2_tscv_t  r2_tscv_v  r2_train   r2_test  \
# 0   0.056164  0.081668   0.813558   0.467669  0.815010  0.501897
# 0   0.057659  0.087050   0.799363   0.447190  0.800546  0.414418
#
#                                                                                                                                               opt_model  \
# 0  {'algorithm': 'auto', 'leaf_size': 36, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 4, 'p': 1, 'weights': 'uniform'}
# 0  {'algorithm': 'auto', 'leaf_size': 36, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 4, 'p': 1, 'weights': 'uniform'}
#
#    ts_mean_true  ts_mean_estim
# 0      0.296046       0.317209
# 0      0.297655       0.317818
